# %% [markdown]
# # Prepare mitosis time series data

# %%
import numpy as np
import matplotlib.pyplot as plt
from cellpose import models
from cellpose.io import imread
import glob
from pathlib import Path
from PIL import Image, ImageSequence
from tqdm import tqdm
import os
import os.path
# from livecellx import segment
from livecellx import core
from livecellx.core import datasets
from livecellx.core.datasets import LiveCellImageDataset, SingleImageDataset
from skimage import measure
from livecellx.core import SingleCellTrajectory, SingleCellStatic

# %%
from livecellx.track.classify_utils import load_class2samples_from_json_dir, load_all_json_dirs
# sample_json_dir = Path("./EBSS_starvation_24h_xy16_annotation")

sample_json_dirs_v0 = [Path(r"./datasets/test_scs_EBSS_starvation/XY1/annotations"), Path(r"./datasets/test_scs_EBSS_starvation/XY16/annotations")]

round1_json_dirs = sample_json_dirs_v0 + [
    Path(r"D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY01\XY01"),
Path(r"D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY09\XY09"),
Path(r"D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY10\XY10"),
Path(r"D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\Yajushi\tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19\XY1\annotations"),
]

round2_json_dirs = [
Path(r"../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/"),
Path(r"../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/"),
Path(r"../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^3/"),
Path(r"../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/"),

] + [
    Path(f"../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY{pos}/annotations") for pos in range(4, 14)
]

round3_json_dirs = [
    Path(r"../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/"),
    Path(r"../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/"),
    Path(r"../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/")
]
sample_json_dirs = sample_json_dirs_v0 + round1_json_dirs + round2_json_dirs + round3_json_dirs
all_class2samples, all_class2sample_extra_info = load_all_json_dirs(sample_json_dirs)
# Out:
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_7.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 11804.71it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_3.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 16453.21it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_0.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 19674.77it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_1.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 18046.49it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_6.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 15149.70it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_2.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 17678.84it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_4.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 19397.35it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_5.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 16949.80it/s]
# |-----> done constructing single cells from json dict
# Loaded 8 annotated samples from datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY1/annotations/apoptosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY1/annotations/normal
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_8.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 11033.18it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_7.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 13984.60it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_3.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 19670.26it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_0.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 16638.56it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_10.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 15698.31it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_11.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 15883.22it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_9.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 19784.45it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_1.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 14224.87it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_6.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 15919.99it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_2.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 20978.51it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_4.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 17583.34it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_5.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 18483.37it/s]
# |-----> done constructing single cells from json dict
# Loaded 12 annotated samples from datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY16/annotations/apoptosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY16/annotations/normal
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_7.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 16320.25it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_3.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 19273.93it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_0.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 16372.37it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_1.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 19523.53it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_6.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 22327.09it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_2.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 18724.57it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_4.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 18615.89it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis/sample_5.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 21379.68it/s]
# |-----> done constructing single cells from json dict
# Loaded 8 annotated samples from datasets/test_scs_EBSS_starvation/XY1/annotations/mitosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY1/annotations/apoptosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY1/annotations/normal
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_8.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 18358.91it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_7.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 16891.56it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_3.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 22255.49it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_0.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 22631.14it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_10.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 17623.13it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_11.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 18796.50it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_9.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 17672.63it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_1.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 14676.39it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_6.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 17549.39it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_2.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 20373.89it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_4.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 20995.75it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis/sample_5.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 19445.77it/s]
# |-----> done constructing single cells from json dict
# Loaded 12 annotated samples from datasets/test_scs_EBSS_starvation/XY16/annotations/mitosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY16/annotations/apoptosis
# Loaded 0 annotated samples from datasets/test_scs_EBSS_starvation/XY16/annotations/normal
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY01\XY01/mitosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY01\XY01/apoptosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY01\XY01/normal
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY09\XY09/mitosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY09\XY09/apoptosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY09\XY09/normal
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY10\XY10/mitosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY10\XY10/apoptosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\shiman_XY10\XY10/normal
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\Yajushi\tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19\XY1\annotations/mitosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\Yajushi\tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19\XY1\annotations/apoptosis
# Loaded 0 annotated samples from D:\LiveCellTracker-dev\datasets\mitosis-annotations-2023\Yajushi\tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19\XY1\annotations/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/mitosis/sample_60fb4728-d4a8-4a6e-9e32-20edb2d8b7cb.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 12692.53it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/mitosis/sample_1e7ea2e5-5f3a-419a-998c-f5c78f90ef1c.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 14332.82it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/mitosis/sample_e268fb42-5ed1-4fc2-9355-c8f274baf3c1.json
# |-----> loaded 9 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 9/9 [00:00<00:00, 15154.05it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/mitosis/sample_631408f1-9597-4ffb-873c-c4ce3081edd2.json
# |-----> loaded 10 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 10/10 [00:00<00:00, 13635.58it/s]
# |-----> done constructing single cells from json dict
# Loaded 4 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_dc722041-bb42-440e-a4e0-1e3da88bf387.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 13301.18it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_5c55b6df-bcd2-4e65-9983-483fae0b7876.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 14200.48it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_dd252489-f9dc-43da-b085-bfbc3b2ed4c0.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 14576.21it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_4361e336-6712-4940-b2c2-dee1948853c7.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 14768.68it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_bacbda7e-4973-4af2-b194-7f32f907b012.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 15096.48it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_3c438aac-db21-4446-b755-4237485f2c3e.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 15663.88it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_07c7e9b9-f31c-4586-aeca-2708f1f018f0.json
# |-----> loaded 10 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 10/10 [00:00<00:00, 13666.68it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_7bddc07e-68ee-4425-a31c-22e8610242bb.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 15052.97it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_75e4af0b-302f-46a0-9eaa-2f14fa97e4c5.json
# |-----> loaded 6 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 6/6 [00:00<00:00, 12729.30it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_2f57adc4-696d-4541-934b-e1b25cef4725.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 14787.61it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_d372a2ed-b367-48e0-af97-a41a3f2ba96d.json
# |-----> loaded 10 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 10/10 [00:00<00:00, 14883.97it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_8f37d95b-8bca-4439-8d14-5e60149bb3cc.json
# |-----> loaded 20 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 20/20 [00:00<00:00, 17088.22it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis/sample_1cdafbf0-ab05-4c8d-b367-c5693b763549.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 15491.43it/s]
# |-----> done constructing single cells from json dict
# Loaded 13 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^3/mitosis/sample_cc1586a9-cd25-4209-bd70-bd4fd11bcbc1.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 13567.53it/s]
# |-----> done constructing single cells from json dict
# Loaded 1 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^3/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^3/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^3/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_12834300-41ab-4e15-b50d-f386482b3cbd.json
# |-----> loaded 9 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 9/9 [00:00<00:00, 12545.28it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_a92298ac-f2b4-402a-a82d-563a6ded8f26.json
# |-----> loaded 10 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 10/10 [00:00<00:00, 14324.81it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_7b7cf42d-6155-4faa-9523-345042e613e8.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 15087.42it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_6643c031-fe39-4b86-add4-69641f9326dd.json
# |-----> loaded 10 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 10/10 [00:00<00:00, 14573.68it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_56a18532-9b89-4498-8e87-32150f2a4e39.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 15137.34it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_012b5ad1-8896-4cd8-a36c-ae97779af9f2.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 15117.09it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_2b292c79-801e-4cb0-a6d2-7aaf1a6b2a2e.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 14563.56it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis/sample_22cbbdee-e6b1-4d8b-b6df-2f76114e4678.json
# |-----> loaded 11 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 11/11 [00:00<00:00, 15166.78it/s]
# |-----> done constructing single cells from json dict
# Loaded 8 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_5f9c927c-bc5a-45cf-836b-2c57128fb4de.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 9300.01it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_0d196674-5452-4fc1-bcb7-85c237958176.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 16523.85it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_772a7661-9c55-4ea2-8315-86abd879fc8f.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 16644.06it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_40ec5402-d8dd-4096-bfc8-d7ec34a6bca0.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 16207.63it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_b78f8918-453f-4287-ae73-a94cec659881.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 17054.64it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_3f3eb3c5-7dbd-4bdf-a3eb-e81966c856be.json
# |-----> loaded 16 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 16/16 [00:00<00:00, 17363.22it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_b70ec819-e18d-44b0-b6fd-9c32697da591.json
# |-----> loaded 20 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 20/20 [00:00<00:00, 18554.76it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_dadd95cb-5fff-42f1-8682-e1f6ca3e6b65.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 16457.47it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis/sample_d1f6587e-d782-40d1-86a5-52c27ccc9643.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 19233.14it/s]
# |-----> done constructing single cells from json dict
# Loaded 9 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis/sample_0375bff7-73c2-410a-9b3e-87fe1a6310bd.json
# |-----> loaded 16 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 16/16 [00:00<00:00, 11528.75it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis/sample_7239d350-69c6-4e4b-880f-54be5c67b55b.json
# |-----> loaded 20 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 20/20 [00:00<00:00, 17367.72it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis/sample_14c8b6c8-4d70-4137-9723-82543094e8bc.json
# |-----> loaded 26 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 26/26 [00:00<00:00, 19035.07it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis/sample_831616f0-5560-4b2a-94af-f86c5b3c56a8.json
# |-----> loaded 17 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 17/17 [00:00<00:00, 17870.47it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis/sample_55ff856c-beb1-45d7-82ac-203b66872c3d.json
# |-----> loaded 17 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 17/17 [00:00<00:00, 16964.83it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis/sample_e4cba3cd-ff66-4e55-a0d0-96150b0c3338.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 18078.90it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis/sample_113f42eb-f011-406a-a6b0-825eaa3a0d6c.json
# |-----> loaded 16 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 16/16 [00:00<00:00, 16396.01it/s]
# |-----> done constructing single cells from json dict
# Loaded 7 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_98385e0a-0a68-4ef0-9122-ad846defd1e0.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 12055.07it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_598cba9a-b53d-4e6a-8c96-17e28a73c22e.json
# |-----> loaded 17 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 17/17 [00:00<00:00, 18704.92it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_a4547668-d294-4f65-b57c-8fb87565d364.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 15401.36it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_7ae10162-6d08-41fb-8890-5050ce696181.json
# |-----> loaded 18 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 18/18 [00:00<00:00, 18855.51it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_8b52259f-18ec-4483-a880-d0d5baa4ef27.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 18477.11it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_4b39d0f8-f12d-4d59-a9ff-63ac25a3b84c.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 17218.00it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_732bc65d-7790-4586-988e-44602e3af32f.json
# |-----> loaded 12 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 12/12 [00:00<00:00, 14997.51it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_7d8bb33e-c0fb-490b-be30-471997cc2277.json
# |-----> loaded 17 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 17/17 [00:00<00:00, 12780.64it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_24fe5305-9a3e-4eb1-bd2c-90d6263d5db8.json
# |-----> loaded 18 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 18/18 [00:00<00:00, 18641.35it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis/sample_89fd2d1f-f41b-41e1-9ad3-5f13112c72c2.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 18230.44it/s]
# |-----> done constructing single cells from json dict
# Loaded 10 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_da1c5d56-8d64-47f6-a3f6-5dd8d9d68c76.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 11216.72it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_04c882b1-513c-44ac-96ab-2d45afef4b93.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 17255.05it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_ec116ecb-d8e5-45f0-82ec-2c56b7122f7e.json
# |-----> loaded 19 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 19/19 [00:00<00:00, 19385.01it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_55025263-2ea6-4cb9-af83-be121e250a1b.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 16719.89it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_292ab374-21b4-41f5-8729-a1a741e9d12b.json
# |-----> loaded 20 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 20/20 [00:00<00:00, 18791.68it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_db0a47f4-da10-4aab-bf6a-01b78acfd784.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 17275.74it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_8e94acdb-7e82-449b-b834-c6db35676065.json
# |-----> loaded 19 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 19/19 [00:00<00:00, 17705.35it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_2f672fab-4b85-451c-bc6d-4944b241491d.json
# |-----> loaded 17 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 17/17 [00:00<00:00, 18631.61it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_ddd94ca8-bcd4-441f-b7fb-a809ca76c8d6.json
# |-----> loaded 18 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 18/18 [00:00<00:00, 17178.04it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_4fd406fa-a391-422c-889a-de15d8c02303.json
# |-----> loaded 17 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 17/17 [00:00<00:00, 13959.12it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_73f01c20-d1be-41f9-87b2-1f1c9fd09e84.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 17991.01it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_5bf4eaf3-305d-416a-ae2d-1c5f77ecb0cb.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 16252.79it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis/sample_f9c6582c-4363-4c4f-ad20-65a4101b85ad.json
# |-----> loaded 13 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 13/13 [00:00<00:00, 15269.10it/s]
# |-----> done constructing single cells from json dict
# Loaded 13 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations/normal
# ...
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_30ece429-4cb1-4c55-b97f-406f954d96ac.json
# |-----> loaded 20 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 20/20 [00:00<00:00, 17232.14it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_02121677-4335-4481-87ab-1f89cc7e1c4b.json
# |-----> loaded 16 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 16/16 [00:00<00:00, 16768.83it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_ef48a78e-9166-4213-ace7-b72a40dbc65a.json
# |-----> loaded 19 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 19/19 [00:00<00:00, 19221.36it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_68ab82fd-5c13-46c8-8070-29925a8980a9.json
# |-----> loaded 16 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 16/16 [00:00<00:00, 18456.78it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_3b13c8c3-b7f3-4c14-975b-1ecd2c718144.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 17687.53it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_b5fd06fb-d1a8-461a-bd90-e560cafc9237.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 17293.72it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_0f27dbbf-0f7a-48f4-8f75-1563369abb40.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 16844.59it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_e171e7f6-b082-4436-9b3a-9d66d67aa401.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 17968.25it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_aa706d71-f358-4d3f-a74e-86f9897c0a3f.json
# |-----> loaded 16 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 16/16 [00:00<00:00, 17664.88it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_da63c7fb-4fd0-484b-a351-efab73910aa2.json
# |-----> loaded 17 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 17/17 [00:00<00:00, 18268.81it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_70c9f3fb-0577-43a5-a64d-239b1ca1710b.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 18558.87it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_16866671-5bdd-473d-a498-befc9db0dc75.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 8958.09it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_c51d2547-95ac-4ea2-8172-18418d9a602d.json
# |-----> loaded 15 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 15/15 [00:00<00:00, 17985.87it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis/sample_2820894c-9e39-4d91-a57e-daa76b66433b.json
# |-----> loaded 14 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 14/14 [00:00<00:00, 17880.71it/s]
# |-----> done constructing single cells from json dict
# Loaded 15 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/apoptosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/normal/sample_2fb94873-66ed-45e0-a608-c80cab1dbaf1.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 10283.76it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/normal/sample_49f8c17c-ee54-47a9-8ade-76d55927f2eb.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13961.07it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/normal/sample_5c72a6c6-d7e7-4f4e-8445-e9c9c2ed9ea3.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 12172.52it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/normal/sample_abc5d023-3524-4687-98d5-f7e860247056.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 11550.01it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/normal/sample_1e9ff241-b2d3-4baf-84de-24606b36764e.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 14448.88it/s]
# |-----> done constructing single cells from json dict
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/apoptosis
# Loaded 5 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/0.25^4/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_c1108855-ef30-4d06-ad18-db1b45890c19.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 10910.49it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_f0b41e04-bfbd-4f34-b223-5a948fa938af.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13078.01it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_6557edc3-da8a-4079-a4b6-897ec67e314f.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13375.91it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_552fac5f-dfc6-4800-b90a-03625ef932c0.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13339.45it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_f0cd4700-6263-4693-a0bb-d34c9848dd32.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13333.39it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_64181b29-736d-4b9a-bb80-d727393571f2.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 12042.71it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_5f48e8f1-8057-4735-9714-f9fdb92b7766.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13987.67it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_f1eb9729-33da-4e83-89a5-84d6558ab97b.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13617.87it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_420743cb-9392-49df-9444-594b2ae61615.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 12776.38it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_2bad39f8-0018-4ea8-a98f-3eff9953e77e.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 11706.59it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal/sample_b0bb8d2a-36c8-4809-a545-2691e2978d2f.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13592.65it/s]
# |-----> done constructing single cells from json dict
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/apoptosis
# Loaded 11 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4/normal
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/normal/sample_a35bf1ee-d155-4aae-a4c3-9d8165188619.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 10580.23it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/normal/sample_ba1603a3-2227-48b4-bbd8-9bd90a6ecd1a.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 11692.60it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/normal/sample_f534d1ab-5eb5-44fb-bc19-8a79df3b5b5f.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 11867.47it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/normal/sample_ea5e20b7-6276-412d-878f-a22a050a744f.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 11613.97it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/normal/sample_d490e612-1cad-4e81-8ab2-715921a0c00e.json
# |-----> loaded 7 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 7/7 [00:00<00:00, 13261.12it/s]
# |-----> done constructing single cells from json dict
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/mitosis
# Loaded 0 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/apoptosis
# Loaded 5 annotated samples from ../datasets/mitosis-annotations-2023/shiman_CXA_normal/C10^3/normal

# %%
len(all_class2samples["mitosis"]), len(all_class2samples["apoptosis"]), len(all_class2samples["normal"])
# Out:
# (197, 0, 21)

# %%
num_zero_len_samples = 0
for key in all_class2samples.keys():
    for sample in all_class2samples[key]:
        if len(sample) == 0:
            num_zero_len_samples += 1
print("num_zero_len_samples: ", num_zero_len_samples)
# Out:
# num_zero_len_samples:  0

# %% [markdown]
# ## Automatically prepare normal samples from segmented normal cells
#
# Note: require tracking done

# %% [markdown]
# Exclude other classes

# %%
# get all scs from class_samples not in normal class
exclude_scs = []
total_non_normal_samples = 0
for class_name, samples in all_class2samples.items():
    if class_name != "normal":
        for sample in samples:
            exclude_scs.extend(sample)
            total_non_normal_samples += 1

exclude_scs = set(exclude_scs)
exclude_scs_ids = {str(sc.id) for sc in exclude_scs}

# %%
# from livecellx.core.sct_operator import create_scs_edit_viewer
# sct_operator = create_scs_edit_viewer(exclude_scs, img_dataset = list(exclude_scs)[0].img_dataset)

# %% [markdown]
# load all single cells, including mitosis and normal ones, for further generating normal samples automatically

# %%
import json
from livecellx.core.single_cell import SingleCellTrajectoryCollection
from livecellx.track.sort_tracker_utils import (
    track_SORT_bbox_from_scs
)

all_scs_json_path = ["./datasets/test_scs_EBSS_starvation/XY1/single_cells.json", "./datasets/test_scs_EBSS_starvation/XY16/single_cells.json"]
# all_scs_json_path = "./datasets/test_scs_EBSS_starvation/XY16/tmp_corrected_scs.json"
sctc = SingleCellTrajectoryCollection()
for json_path in all_scs_json_path:
    print("json path:", json_path)
    _scs = SingleCellStatic.load_single_cells_json(json_path)
    tmp_sctc = track_SORT_bbox_from_scs(_scs, raw_imgs=_scs[0].img_dataset, min_hits=3, max_age=3)
    tids = set(sctc.get_all_tids())
    if len(tids) != 0:
        max_tid = max(tids)
    else:
        max_tid = 0
    for tid, traj in tmp_sctc:
        traj.meta["src_dir"] = json_path
        traj.track_id = tid + max_tid + 1
        sctc.add_trajectory(traj)
        traj_scs = traj.get_all_scs()
        for sc in traj_scs:
            sc.meta["src_dir"] = json_path
    del tmp_sctc

all_scs = SingleCellStatic.load_single_cells_jsons(all_scs_json_path)
# Out:
# json path: ./datasets/test_scs_EBSS_starvation/XY1/single_cells.json
# |-----> loading single cells from json file: ./datasets/test_scs_EBSS_starvation/XY1/single_cells.json
# |-----> loaded 3369 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 3369/3369 [00:00<00:00, 17581.86it/s]
# |-----> done constructing single cells from json dict
# json path: ./datasets/test_scs_EBSS_starvation/XY16/single_cells.json
# |-----> loading single cells from json file: ./datasets/test_scs_EBSS_starvation/XY16/single_cells.json
# |-----> loaded 6605 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 6605/6605 [00:01<00:00, 4050.49it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ./datasets/test_scs_EBSS_starvation/XY1/single_cells.json
# |-----> loaded 3369 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 3369/3369 [00:00<00:00, 18440.75it/s]
# |-----> done constructing single cells from json dict
# |-----> loading single cells from json file: ./datasets/test_scs_EBSS_starvation/XY16/single_cells.json
# |-----> loaded 6605 single cells
# |-----> constructing single cells from json dict...
# constructing single cells from json dict: 100%|██████████| 6605/6605 [00:01<00:00, 4106.88it/s]
# |-----> done constructing single cells from json dict

# %%
# with open("./EBSS_starvation_24h_xy16_annotation/single_cell_trajectory_collection.json", "r") as file:
#     json_dict = json.load(file)
# sctc = SingleCellTrajectoryCollection().load_from_json_dict(json_dict)

# %%
# set numpy seed
seed = 0
np.random.seed(seed)

objective_sample_num = total_non_normal_samples * 10

normal_frame_len_range = (3, 10)
counter = 0
normal_samples = []
normal_samples_extra_info = []
max_trial_counter = 100000
while counter < objective_sample_num and max_trial_counter > 0:
    # randomly select a sct from sctc
    # generate a list of scs
    track_id = np.random.choice(list(sctc.track_id_to_trajectory.keys()))  
    sct = sctc.get_trajectory(track_id)
    # randomly select a length
    frame_len = np.random.randint(*normal_frame_len_range)
    # generate a sample
    times = list(sct.timeframe_to_single_cell.keys())
    times = sorted(times)
    if len(times) <= frame_len:
        continue
    start_idx = np.random.randint(0, len(times) - frame_len)
    start_time = times[start_idx]
    end_time = times[start_idx + frame_len - 1]

    sub_sct = sct.subsct(start_time, end_time)

    is_some_sc_in_exclude_scs = False
    for time, sc in sub_sct.timeframe_to_single_cell.items():
        # print("sc.id:", sc.id, type(sc.id))
        if str(sc.id) in exclude_scs_ids:
            is_some_sc_in_exclude_scs = True
            break
    if is_some_sc_in_exclude_scs:
        print("some sc in the exclude scs list")
        continue
    
    new_sample = []
    for time, sc in sub_sct.timeframe_to_single_cell.items():
        new_sample.append(sc)
    normal_samples.append(new_sample)
    normal_samples_extra_info.append({"src_dir": sub_sct.get_all_scs()[0].meta["src_dir"]})
    counter += 1
    max_trial_counter -= 1

print("# of normal samples:", len(normal_samples))
print("# of normal samples extra info:", len(normal_samples_extra_info))
# Out:
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# some sc in the exclude scs list
# # of normal samples: 1970
# # of normal samples extra info: 1970

# %%
all_class2samples["normal"].extend(normal_samples)
all_class2sample_extra_info["normal"].extend(normal_samples_extra_info)

# %%
len(all_class2samples["normal"]), len(all_class2sample_extra_info["normal"])
# Out:
# (1991, 1991)

# %% [markdown]
# Add start and end time to all_class2sample_extra_info

# %%
for class_name, samples in all_class2samples.items():
    print(class_name, len(samples))
    class_extra_infos = all_class2sample_extra_info[class_name]
    for sample_idx, sample in enumerate(samples):
        if len(sample) == 0:
            continue
        sample_extra_info = class_extra_infos[sample_idx]
        min_time = None
        max_time = None
        for sc in sample:
            if min_time is None or sc.timeframe < min_time:
                min_time = sc.timeframe
            if max_time is None or sc.timeframe > max_time:
                max_time = sc.timeframe
        sample_extra_info["start_time"] = min_time
        sample_extra_info["end_time"] = max_time
        sample_extra_info["first_sc_id"] = sample[0].id
# Out:
# mitosis 197
# apoptosis 0
# normal 1991

# %%
[len(all_class2sample_extra_info[cls]) for cls in all_class2sample_extra_info.keys()]
# Out:
# [197, 0, 1991]

# %% [markdown]
# ## Prepare videos and annotations for MMDetection

# %%
classes = all_class2samples.keys()
classes
# Out:
# dict_keys(['mitosis', 'apoptosis', 'normal'])

# %%
from livecellx.core.utils import gray_img_to_rgb, rgb_img_to_gray
from livecellx.preprocess.utils import normalize_img_to_uint8

# %%
from livecellx.track.classify_utils import video_frames_and_masks_from_sample, combine_video_frames_and_masks

# %%
from typing import List
import cv2
import numpy as np
import pandas as pd

from livecellx.core.sc_video_utils import gen_mp4_from_frames, gen_class2sample_samples, gen_samples_mp4s

# ver = "10-st" # single trajectory ver
# ver = "test" # single trajectory ver
# ver = "11-st-run0"
# MAKE_SINGLE_CELL_TRAJ_SAMPLES = True
# DROP_MITOSIS_DIV = False

# ver = "10-drop-div"
# DROP_MITOSIS_DIV = True
# ver = "-test"

# ver = "11-drop-div"
# MAKE_SINGLE_CELL_TRAJ_SAMPLES = False
# DROP_MITOSIS_DIV = True

# ver = "12-st"
# MAKE_SINGLE_CELL_TRAJ_SAMPLES = True
# DROP_MITOSIS_DIV = False

# ver = "12-drop-div"
# MAKE_SINGLE_CELL_TRAJ_SAMPLES = False
# DROP_MITOSIS_DIV = True

# ver = "12-all"
# MAKE_SINGLE_CELL_TRAJ_SAMPLES = False
# DROP_MITOSIS_DIV = False

# ver = "test-all"

# ver = "13-inclusive-with-mitosis-type"
ver = "14-inclusive"
MAKE_SINGLE_CELL_TRAJ_SAMPLES = False
DROP_MITOSIS_DIV = False
INCLUDE_ALL = True

DEBUG = False

# %%
data_dir = Path(f'notebook_results/mmaction_train_data_v{ver}')
class_labels = ['mitosis', 'apoptosis', 'normal']
class_label = "mitosis"
frame_types = ["video", "mask", "combined"]
fps = 3

# 1 instead of 0 to prevent the decord (used by mmdetection) python package error
padding_pixels = [1, 20, 40, 50, 100, 200, 400]

# %%
# split train and test data

# get #samples from all_class2samples
_split = 0.8

train_class2samples = {}
test_class2samples = {}
train_class2sample_extra_info = {}
test_class2sample_extra_info = {}

# randomize train and test data
for key in all_class2samples.keys():
    randomized_indices = np.random.permutation(len(all_class2samples[key])).astype(int)
    split_idx = int(len(all_class2samples[key]) * _split)
    _train_indices = randomized_indices[:split_idx]
    _test_indices = randomized_indices[split_idx:]
    train_class2samples[key] = np.array(all_class2samples[key], dtype=object)[_train_indices]
    test_class2samples[key] = np.array(all_class2samples[key], dtype=object)[_test_indices]

    train_class2samples[key] = list(train_class2samples[key])
    test_class2samples[key] = list(test_class2samples[key])

    train_class2sample_extra_info[key] = np.array(all_class2sample_extra_info[key], dtype=object)[_train_indices]
    test_class2sample_extra_info[key] = np.array(all_class2sample_extra_info[key], dtype=object)[_test_indices]
    train_class2sample_extra_info[key] = list(train_class2sample_extra_info[key])
    test_class2sample_extra_info[key] = list(test_class2sample_extra_info[key])


# # for debug
if DEBUG:
    test_sample_num = 3
     padding_pixels = [1, 20]
    train_class2samples = {key: value[:test_sample_num] for key, value in all_class2samples.items()}
    test_class2samples = {key: value[:test_sample_num] for key, value in all_class2samples.items()}
    train_class2sample_extra_info = {key: value[:test_sample_num] for key, value in all_class2sample_extra_info.items()}
    test_class2sample_extra_info = {key: value[:test_sample_num] for key, value in all_class2sample_extra_info.items()}

# %%
len(train_class2samples["normal"]), len(test_class2samples["normal"])
# Out:
# (1592, 399)

# %%
len(train_class2samples["mitosis"]), len(test_class2samples["mitosis"])
# Out:
# (157, 40)

# %%
video_frames_and_masks_from_sample(train_class2samples["normal"][0])[0][0].shape
# train_class2samples["normal"][6][1].show_panel()
# Out:
# (81, 98, 3)

# %%
import importlib
import livecellx
importlib.reload(livecellx.track.classify_utils)
# Out:
# <module 'livecellx.track.classify_utils' from '/home/ken67/LiveCellTracker-dev/livecellx/track/classify_utils.py'>

# %% [markdown]
# Check some sample generation

# %%
idx_to_check = 0
video_frames, video_frame_masks = video_frames_and_masks_from_sample(train_class2samples["normal"][idx_to_check], padding_pixels=0)
print("video frames dtype:", video_frames[0].dtype)
print("video frames shape:", video_frames[0].shape)
print("video frame masks dtype:", video_frame_masks[0].dtype)
print("video frame masks shape:", video_frame_masks[0].shape)
combined_frames = livecellx.track.classify_utils.combine_video_frames_and_masks(video_frames, video_frame_masks, edt_transform=True)
combined_frames = np.array(combined_frames).astype(np.uint8)
# combined_frames = np.maximum(combined_frames - 1, 0).astype(np.uint8)
print("combined_frames shape: ", combined_frames[0].shape)
gen_mp4_from_frames(combined_frames, "./test_video_output.mp4", fps=1)
# Out:
# video frames dtype: uint8
# video frames shape: (81, 98, 3)
# video frame masks dtype: uint8
# video frame masks shape: (81, 98, 3)
# combined_frames shape:  (81, 98, 3)

# %% [markdown]
# Visually check the generated frames' values

# %%
# channel = 2
# plt.imshow(combined_frames[0][..., channel])
# combined_frames[1][..., channel].max(), combined_frames[1][..., 0].shape

# %%
np.array(combined_frames).flatten().min()
# Out:
# 0

# %% [markdown]
# Make single cell trajectories only (ONE cell per time frame)

# %%
from typing import Dict
from livecellx.track.data_prep_utils import is_one_sc_each_time
from livecellx.track.data_prep_utils import make_one_cell_per_timeframe_for_class2samples, make_one_cell_per_timeframe_helper, make_one_cell_per_timeframe_samples



sample = train_class2samples["mitosis"][0]

# %%
[sc.timeframe for sc in sample]
# Out:
# [106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 117, 118, 118]

# %%
len(make_one_cell_per_timeframe_samples(sample))
# Out:
# 4

# %%
if MAKE_SINGLE_CELL_TRAJ_SAMPLES:
    train_class2samples, train_class2sample_extra_info = make_one_cell_per_timeframe_for_class2samples(train_class2samples, train_class2sample_extra_info)
    test_class2samples, test_class2sample_extra_info = make_one_cell_per_timeframe_for_class2samples(test_class2samples, test_class2sample_extra_info)

# %% [markdown]
# Drop the cell divison part for easier inference durign testing

# %%
from livecellx.track.data_prep_utils import drop_multiple_cell_frames_in_samples

if DROP_MITOSIS_DIV:
    train_class2samples = drop_multiple_cell_frames_in_samples(train_class2samples)
    test_class2samples = drop_multiple_cell_frames_in_samples(test_class2samples)

# %% [markdown]
# Include original, drop-div and st

# %%
train_class2sample_extra_info
# Out:
# {'mitosis': [{'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 106,
#    'end_time': 118,
#    'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 258,
#    'end_time': 267,
#    'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 82,
#    'end_time': 92,
#    'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 98,
#    'end_time': 109,
#    'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 109,
#    'end_time': 118,
#    'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 159,
#    'end_time': 183,
#    'first_sc_id': 'b4ac268b-b9bb-4b83-bd5a-858c9f3af094'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 121,
#    'end_time': 136,
#    'first_sc_id': 'a0dbfe2b-c48c-4bf4-b8d2-760f4495de1a'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 173,
#    'end_time': 184,
#    'first_sc_id': '999c92cd-7c3c-4b84-a8b0-1acf03215b01'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#    'start_time': 155,
#    'end_time': 168,
#    'first_sc_id': '2c92a009-46a1-4aae-8930-d113c754bac4'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 260,
#    'end_time': 277,
#    'first_sc_id': '9fe54c26-45a2-42af-b9da-32f4c9909e40'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 273,
#    'end_time': 289,
#    'first_sc_id': '02c376bf-5f23-470d-94d0-3513139a1164'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#    'start_time': 84,
#    'end_time': 96,
#    'first_sc_id': '559d0a8d-3186-4392-9d1e-f936fdd6510f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 243,
#    'end_time': 256,
#    'first_sc_id': 'f36b598c-f7e0-48bb-b6bb-a90f7be0a421'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 55,
#    'end_time': 62,
#    'first_sc_id': '456a5f3d-f1bb-483e-ad12-103346a6ca3d'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 224,
#    'end_time': 235,
#    'first_sc_id': '07acaf1f-b081-402d-8b12-4c33545a959f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 46,
#    'end_time': 58,
#    'first_sc_id': '4d662ffd-06be-46f2-a8bd-21bd26c08b79'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 151,
#    'end_time': 159,
#    'first_sc_id': 'beceb2c6-b2bb-49d4-98ba-710b158e45e2'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#    'start_time': 175,
#    'end_time': 183,
#    'first_sc_id': 'c92fa4a6-c2fc-4b1b-9a62-b1edfc1a98b0'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 154,
#    'end_time': 163,
#    'first_sc_id': 'ca123ef6-df57-4a94-a67c-6193f54513c8'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 139,
#    'end_time': 148,
#    'first_sc_id': 'e14f1a39-f0fc-44e7-852b-8c42ffef0998'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#    'start_time': 272,
#    'end_time': 291,
#    'first_sc_id': '24a16a9c-4cef-4f2e-9e19-7803b167c98e'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 139,
#    'end_time': 148,
#    'first_sc_id': 'e14f1a39-f0fc-44e7-852b-8c42ffef0998'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 66,
#    'end_time': 79,
#    'first_sc_id': 'ba6ddc87-1a93-4d6c-86be-57e8e561bd87'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 127,
#    'end_time': 136,
#    'first_sc_id': '5a688a30-c08f-4588-9e7e-cd5d6fb460a9'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 23,
#    'end_time': 35,
#    'first_sc_id': '4c750589-6b92-4e52-a1be-2bcbeed90f7e'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 235,
#    'end_time': 246,
#    'first_sc_id': '9f0cfbca-a1ec-47b2-a1c2-44ec6cae6202'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 158,
#    'end_time': 171,
#    'first_sc_id': '8b4f95ef-7bed-4a47-b68f-bd54880f7ccb'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#    'start_time': 192,
#    'end_time': 204,
#    'first_sc_id': '42125368-8092-48bb-add7-3613a67a22d3'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#    'start_time': 19,
#    'end_time': 26,
#    'first_sc_id': '4f32e9eb-338c-474c-ba51-3626d7fb326f'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 189,
#    'end_time': 197,
#    'first_sc_id': '9be5efae-94d4-4242-ae76-3624be7ae695'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 127,
#    'end_time': 137,
#    'first_sc_id': '13775974-804f-4e18-b56d-0bbf4302f603'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 2,
#    'end_time': 15,
#    'first_sc_id': 'de2f64db-23c7-416b-bb09-fcf9197d9e2d'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 94,
#    'end_time': 105,
#    'first_sc_id': '057a319d-093f-4fc0-9ecd-47b7446417b6'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 196,
#    'end_time': 205,
#    'first_sc_id': '9935c28b-11ce-44ca-9077-55d19c4938a6'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4'),
#    'start_time': 146,
#    'end_time': 154,
#    'first_sc_id': '0ec6cfd6-82c1-4746-a8be-4bd6d399b407'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 258,
#    'end_time': 267,
#    'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#    'start_time': 252,
#    'end_time': 265,
#    'first_sc_id': '5289f931-752e-4934-ab6a-10ebc91a5159'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 57,
#    'end_time': 64,
#    'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 38,
#    'end_time': 49,
#    'first_sc_id': '58d3936b-3cd2-410d-958c-e0289c3167a5'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 125,
#    'end_time': 134,
#    'first_sc_id': '86c31717-f4b6-4f80-a081-27217a967bb5'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 272,
#    'end_time': 282,
#    'first_sc_id': 'f980f6de-1c28-4dfc-83fe-3dadfca0aa21'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 203,
#    'end_time': 216,
#    'first_sc_id': '983bcd65-dbfe-48d2-9949-a904d93024e3'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 156,
#    'end_time': 163,
#    'first_sc_id': '13b3df9b-90c8-44f7-85e9-6860bf26573f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 126,
#    'end_time': 137,
#    'first_sc_id': '086ae042-97fe-4c5f-bc36-feff453388d7'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#    'start_time': 30,
#    'end_time': 40,
#    'first_sc_id': '5643ff85-8a4e-4619-9afd-721ad8d7e551'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 188,
#    'end_time': 200,
#    'first_sc_id': '11fd4ca5-4188-41d7-a6eb-a0f0e92b8798'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#    'start_time': 117,
#    'end_time': 128,
#    'first_sc_id': 'cf01a3a3-cedd-4007-a264-889076755938'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 224,
#    'end_time': 235,
#    'first_sc_id': '07acaf1f-b081-402d-8b12-4c33545a959f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#    'start_time': 144,
#    'end_time': 152,
#    'first_sc_id': '1570f176-15d2-4e63-9bed-d7f3b06f8df1'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 138,
#    'end_time': 148,
#    'first_sc_id': 'd26a92f6-d612-46da-bcb6-e7b2cf4d113d'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 234,
#    'end_time': 246,
#    'first_sc_id': '7e96f0a0-edd8-4390-b100-2d3425ed0808'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#    'start_time': 148,
#    'end_time': 162,
#    'first_sc_id': 'e7d3511c-53e9-4632-b41d-dd61620399b4'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 6,
#    'end_time': 19,
#    'first_sc_id': 'fd3cf52a-0a4e-44bb-86b7-b58e31cf2de2'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 104,
#    'end_time': 114,
#    'first_sc_id': 'd89799b1-3ff5-42cc-ad50-f5654428ac38'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 240,
#    'end_time': 251,
#    'first_sc_id': '1a548f3a-a903-4e73-88c9-a2c1669e1525'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 171,
#    'end_time': 182,
#    'first_sc_id': 'de01d271-de59-4488-a526-f5c6f58e5eec'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 109,
#    'end_time': 119,
#    'first_sc_id': '0fa899ed-db36-4bc0-a49b-62a46e580b2e'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 51,
#    'end_time': 67,
#    'first_sc_id': '3e6cbc6d-a8ad-4d51-bc64-0e49e4107f7c'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#    'start_time': 49,
#    'end_time': 60,
#    'first_sc_id': 'b1a8a6ab-4a77-4f06-8358-fe8dccf5ab19'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#    'start_time': 278,
#    'end_time': 292,
#    'first_sc_id': '16385ded-c2c7-4051-8eff-7428ff94374b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 274,
#    'end_time': 288,
#    'first_sc_id': '22f7030c-e635-466e-b89d-8f829194a3ad'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 81,
#    'end_time': 94,
#    'first_sc_id': 'bbe9b05a-fb31-470f-99b1-1c1189a69f00'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 156,
#    'end_time': 165,
#    'first_sc_id': 'ed3c97de-c03c-4f20-9450-ba347f735b1f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 94,
#    'end_time': 106,
#    'first_sc_id': 'be628c2a-304e-4ef7-bd28-c5af90eca5c7'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 131,
#    'end_time': 144,
#    'first_sc_id': '064b2a8a-7390-42ee-ae4f-d89c94506985'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 169,
#    'end_time': 180,
#    'first_sc_id': '6fcd509f-fddc-4fb9-81f6-f00faf2a8b2f'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 74,
#    'end_time': 83,
#    'first_sc_id': '61a0958d-7e26-4418-a9a5-05d43da69283'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 100,
#    'end_time': 111,
#    'first_sc_id': '96f34ead-1445-4664-9dd9-abd3ce77907a'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#    'start_time': 64,
#    'end_time': 70,
#    'first_sc_id': '1282868e-4855-4d1c-9e1a-400b794a92e6'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 102,
#    'end_time': 113,
#    'first_sc_id': '86a6962a-7ec5-429f-87f4-27d1775eae7b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#    'start_time': 75,
#    'end_time': 87,
#    'first_sc_id': 'dbdc419d-3269-4045-8b44-d9cc144ce407'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 274,
#    'end_time': 283,
#    'first_sc_id': 'd15196f3-abe6-41f0-a2b5-2b7ca2643da2'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^3'),
#    'start_time': 139,
#    'end_time': 150,
#    'first_sc_id': '52038fa9-d237-44a4-a293-020feb739fe3'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 276,
#    'end_time': 289,
#    'first_sc_id': 'd4e080fe-a285-4746-80c3-8b49c5e03680'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 68,
#    'end_time': 77,
#    'first_sc_id': '6d8a6cc8-1afe-4c1f-bebd-b19ad51e40cb'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 215,
#    'end_time': 225,
#    'first_sc_id': '305ae37c-d948-4953-b18e-45435f789b2a'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 173,
#    'end_time': 183,
#    'first_sc_id': 'e60e4ee1-c76d-4108-918e-8e2148513f39'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 274,
#    'end_time': 283,
#    'first_sc_id': 'b8d90813-8b7d-460d-ab7f-2188f338fd04'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 85,
#    'end_time': 99,
#    'first_sc_id': '5c20bd80-4fdb-47ec-bfaf-107275b52388'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 56,
#    'end_time': 68,
#    'first_sc_id': '68b6a5e9-67af-4bbb-9e2a-37eec1ed771f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 8,
#    'end_time': 20,
#    'first_sc_id': 'bca30362-81d7-4af2-809f-8289272c0326'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 57,
#    'end_time': 67,
#    'first_sc_id': 'a9c5f6bd-babc-42cc-a32a-c6c72860415b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 277,
#    'end_time': 287,
#    'first_sc_id': '35fa9ff0-3996-479e-9921-4603be117c57'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#    'start_time': 165,
#    'end_time': 174,
#    'first_sc_id': 'a0e8263d-cc77-420c-b916-ab2fe3ef9947'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#    'start_time': 60,
#    'end_time': 69,
#    'first_sc_id': '49edeb21-c133-49b1-a741-98ccbae8af43'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 92,
#    'end_time': 104,
#    'first_sc_id': '9d939a81-2379-4a36-9137-61953125a145'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 53,
#    'end_time': 62,
#    'first_sc_id': '9e35fa64-8392-48d0-a788-c548c0793a39'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 68,
#    'end_time': 81,
#    'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 227,
#    'end_time': 234,
#    'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 227,
#    'end_time': 234,
#    'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#    'start_time': 209,
#    'end_time': 219,
#    'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 77,
#    'end_time': 87,
#    'first_sc_id': '2c1833d6-109e-48e5-8028-3f57ccc0123a'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 104,
#    'end_time': 116,
#    'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 57,
#    'end_time': 64,
#    'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 50,
#    'end_time': 58,
#    'first_sc_id': '310226a1-5e47-4a0a-b53f-543e36743f56'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 127,
#    'end_time': 140,
#    'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 146,
#    'end_time': 160,
#    'first_sc_id': '928d01d9-4383-4d3c-a199-c99eec4f29cb'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 170,
#    'end_time': 185,
#    'first_sc_id': '3da987ad-753f-486e-8bdb-c7fb67049808'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 241,
#    'end_time': 252,
#    'first_sc_id': '2855106b-9063-4e2f-b7ac-43d756729dbf'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 20,
#    'end_time': 30,
#    'first_sc_id': 'a1a8886c-c756-496e-b18e-feab7fd62c68'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#    'start_time': 47,
#    'end_time': 55,
#    'first_sc_id': 'd36bdf19-f8bb-4713-a667-c6828516f100'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 290,
#    'end_time': 301,
#    'first_sc_id': '41f77cef-ed1f-4b3c-8a59-3008f9f57f71'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 86,
#    'end_time': 95,
#    'first_sc_id': 'd75631bf-b955-49f2-80a9-3fd2fbfa7d20'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 105,
#    'end_time': 115,
#    'first_sc_id': '138ef752-af6d-491a-8ab8-420abc0d9a4b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#    'start_time': 74,
#    'end_time': 87,
#    'first_sc_id': '1ac75e2b-daf1-4285-a687-227783c811a5'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 92,
#    'end_time': 106,
#    'first_sc_id': '3b483c8c-cb71-42fe-b2e1-69257670f884'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 127,
#    'end_time': 135,
#    'first_sc_id': '0ae7ad67-fb29-4e5b-ab6a-7c91f05ebaf2'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 145,
#    'end_time': 159,
#    'first_sc_id': '38fb72df-d715-482f-875d-3241f6b8c751'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 117,
#    'end_time': 127,
#    'first_sc_id': '337534a0-2b25-4043-9390-575af44876d9'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 237,
#    'end_time': 248,
#    'first_sc_id': 'a7d0f1bc-3fd9-4518-b470-e30971b9acb4'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 287,
#    'end_time': 297,
#    'first_sc_id': '06962166-324f-476e-92ef-36d4a8ec92f7'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 248,
#    'end_time': 258,
#    'first_sc_id': '718998b6-72af-4a0d-a10d-4f013d6ffb60'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#    'start_time': 169,
#    'end_time': 179,
#    'first_sc_id': '15c99ebd-15ce-4467-860c-b5f1758577ba'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 137,
#    'end_time': 150,
#    'first_sc_id': 'fd488fe9-44ff-415b-9590-010be5ed9a02'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 177,
#    'end_time': 186,
#    'first_sc_id': '55a1156a-f85e-4a6a-a7e1-fdc18bd4697f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 17,
#    'end_time': 26,
#    'first_sc_id': 'd917e087-6ef7-430b-83fe-ca96be01747c'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 42,
#    'end_time': 52,
#    'first_sc_id': '45670ea4-3779-4fa1-b6c3-2d6164b425d9'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#    'start_time': 194,
#    'end_time': 206,
#    'first_sc_id': 'f3769191-0a03-4688-931f-e3cfb176325b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#    'start_time': 254,
#    'end_time': 270,
#    'first_sc_id': 'd5bf6f73-80f0-4cf3-803e-2fef0fa2bec0'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 280,
#    'end_time': 290,
#    'first_sc_id': '5a17b096-fcdd-474b-8364-12630fe95d82'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#    'start_time': 2,
#    'end_time': 12,
#    'first_sc_id': 'b469d334-c05b-43ab-a4f0-3410fafffc10'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 22,
#    'end_time': 33,
#    'first_sc_id': '99edddb4-6bbb-4f8c-aa62-b5588e9d9f63'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 22,
#    'end_time': 34,
#    'first_sc_id': 'cba0f157-6729-4b87-8e7d-0f22ac5db49f'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 221,
#    'end_time': 232,
#    'first_sc_id': 'cd7c706c-9c67-4955-a50c-9ece316e01a3'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 110,
#    'end_time': 121,
#    'first_sc_id': '31b17d1d-f17c-458c-8cc2-51a05186b616'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 117,
#    'end_time': 126,
#    'first_sc_id': 'db7abf5d-484b-485d-83a3-462a47512e70'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 146,
#    'end_time': 155,
#    'first_sc_id': 'ff6d8d33-cc51-4eda-a416-ceeb50c01fb0'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 126,
#    'end_time': 138,
#    'first_sc_id': 'ee450fbc-e942-4498-adc1-743416d0ba0e'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#    'start_time': 175,
#    'end_time': 190,
#    'first_sc_id': '31929807-b3a2-413f-a846-dfe9ef00dbff'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 239,
#    'end_time': 249,
#    'first_sc_id': '5fc754b1-e519-43d7-8f8b-abefb8f15036'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 125,
#    'end_time': 134,
#    'first_sc_id': '86c31717-f4b6-4f80-a081-27217a967bb5'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#    'start_time': 237,
#    'end_time': 248,
#    'first_sc_id': '4eb85515-9d14-46c6-943c-ff674997524e'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#    'start_time': 198,
#    'end_time': 207,
#    'first_sc_id': '109ef75a-1f0b-4e40-95d6-4e2a2fa53948'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 92,
#    'end_time': 104,
#    'first_sc_id': '9d939a81-2379-4a36-9137-61953125a145'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#    'start_time': 125,
#    'end_time': 137,
#    'first_sc_id': '977f0875-6ecc-45f6-a53a-0bebe9687705'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 107,
#    'end_time': 118,
#    'first_sc_id': '8628ebbb-04fd-40ce-a839-03b20d50569b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 144,
#    'end_time': 153,
#    'first_sc_id': '40225d52-b35a-4317-969b-7f0461b1e892'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 109,
#    'end_time': 118,
#    'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#    'start_time': 117,
#    'end_time': 127,
#    'first_sc_id': '4ae4e2c5-795c-4504-9e99-796adc43b44c'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 190,
#    'end_time': 205,
#    'first_sc_id': '417bfb8c-d841-454e-9226-8e80bd619a75'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 234,
#    'end_time': 247,
#    'first_sc_id': '0ba42739-94de-4a7e-b982-11c6c7575538'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 114,
#    'end_time': 125,
#    'first_sc_id': 'f1db5924-ec8d-49c1-a8e1-4bd1863cdf61'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 94,
#    'end_time': 106,
#    'first_sc_id': 'd27b838c-2d3c-4c86-8610-a631dfd89f95'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 153,
#    'end_time': 162,
#    'first_sc_id': 'dacc7ce2-0eb6-46da-a648-0f607a1a987b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 76,
#    'end_time': 95,
#    'first_sc_id': '3dc57e89-1035-431c-b23f-2fcea9cdf3bc'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#    'start_time': 280,
#    'end_time': 290,
#    'first_sc_id': 'a654f191-8e47-47eb-a2aa-697c9d979ee1'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#    'start_time': 173,
#    'end_time': 183,
#    'first_sc_id': '7f933c39-e3d4-4741-a6a0-f00020948a3b'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#    'start_time': 141,
#    'end_time': 159,
#    'first_sc_id': '327e5534-1c65-4ba2-9e73-099124b69de4'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#    'start_time': 156,
#    'end_time': 165,
#    'first_sc_id': 'ed3c97de-c03c-4f20-9450-ba347f735b1f'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#    'start_time': 37,
#    'end_time': 45,
#    'first_sc_id': 'b7bb10ea-e41d-419e-9e18-c10e1086af11'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#    'start_time': 124,
#    'end_time': 132,
#    'first_sc_id': '7c9c56ba-575a-4182-8cf8-e99b3cd7d491'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 127,
#    'end_time': 136,
#    'first_sc_id': '5a688a30-c08f-4588-9e7e-cd5d6fb460a9'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 106,
#    'end_time': 118,
#    'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 214,
#    'end_time': 224,
#    'first_sc_id': 'af8a8cc6-8eb6-4897-95e3-d3c796602d31'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#    'start_time': 121,
#    'end_time': 134,
#    'first_sc_id': '1a77ecd7-f531-4fd0-90e5-4f69e2c9ddcc'},
#   {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#    'start_time': 74,
#    'end_time': 83,
#    'first_sc_id': '61a0958d-7e26-4418-a9a5-05d43da69283'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#    'start_time': 67,
#    'end_time': 78,
#    'first_sc_id': '4ac9dcf8-aff6-4728-bfe1-ee2b52d988c5'}],
#  'apoptosis': [],
#  'normal': [{'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 264,
#    'end_time': 270,
#    'first_sc_id': '76c5982e-1bde-476c-9b2b-0c7b6bf35108'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 243,
#    'end_time': 254,
#    'first_sc_id': '8d5c3777-425b-42d8-b6b5-ed130eafab72'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 103,
#    'end_time': 110,
#    'first_sc_id': 'd1337574-ab7e-4cd0-a6ab-692d61f9d992'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 276,
#    'end_time': 280,
#    'first_sc_id': '4d945e5b-0343-4ed8-9ea2-359662c78eff'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 183,
#    'end_time': 191,
#    'first_sc_id': '2e0d08ef-cabc-44b1-9264-f2f34ad75ca8'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 69,
#    'end_time': 71,
#    'first_sc_id': '54a4caeb-672f-48a7-86eb-67d2e014fc80'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 264,
#    'end_time': 270,
#    'first_sc_id': '5d50ef06-2d9d-46e6-ae9c-85b9757eb2a5'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 143,
#    'end_time': 149,
#    'first_sc_id': '04454907-a4e3-4e41-a858-9a6c4e62e7e3'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 69,
#    'end_time': 71,
#    'first_sc_id': 'e6dc7bc6-9b0f-4f4c-adf1-583b616cf887'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 19,
#    'end_time': 21,
#    'first_sc_id': '71230faf-cda2-4bbc-878c-8ded0daba233'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 65,
#    'end_time': 68,
#    'first_sc_id': 'f056b178-6258-4b53-a454-3ffae4a6ed14'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 17,
#    'end_time': 24,
#    'first_sc_id': '5b2cbd2c-8917-480e-8a28-f98d0986b6f6'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 0,
#    'end_time': 8,
#    'first_sc_id': '013fbbb7-4130-423f-91ee-5de799044853'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 14,
#    'end_time': 19,
#    'first_sc_id': 'b8e2d1ae-1a01-4c2c-9eb6-71066fb9dc96'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 135,
#    'end_time': 140,
#    'first_sc_id': '76a7bbc5-bbd1-45ad-8bb1-0f8d724a3b0a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 257,
#    'end_time': 260,
#    'first_sc_id': 'cc3d430a-0068-4fe5-98cb-d02a4b901a59'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 176,
#    'end_time': 181,
#    'first_sc_id': '84ef1a5b-5ea5-497b-8da3-e30543054d37'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 275,
#    'end_time': 283,
#    'first_sc_id': 'eb96b3bc-8ee6-40ce-8f80-b09bedec9b8a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 241,
#    'end_time': 245,
#    'first_sc_id': '787c0be4-44ed-4cc1-bc6d-00732dc95c85'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 188,
#    'end_time': 194,
#    'first_sc_id': '4524806b-18a0-4cbb-a043-6a8b1bc13a62'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 107,
#    'end_time': 114,
#    'first_sc_id': '6d6fc555-47d1-46c3-b0f8-1d2a4d0d1611'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 252,
#    'end_time': 254,
#    'first_sc_id': '2c45a02a-9cc4-491a-9f99-aafc1692da6d'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 258,
#    'end_time': 261,
#    'first_sc_id': 'c2d418f6-6d5f-4412-9e04-3cc673476e64'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 226,
#    'end_time': 229,
#    'first_sc_id': 'adf0a277-d440-49c9-b1a2-6c04c2c8c3b1'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 175,
#    'end_time': 177,
#    'first_sc_id': '1ca259ff-ac16-4ff3-b737-f658e314554f'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 62,
#    'end_time': 65,
#    'first_sc_id': '879bfc5e-1b7b-434c-84a6-493fc36a1632'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 277,
#    'end_time': 279,
#    'first_sc_id': '87a1d78f-dfd5-4562-a029-7b70ee812b68'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 189,
#    'end_time': 196,
#    'first_sc_id': 'fcbc4978-32c8-443e-b992-9b527659d56e'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 271,
#    'end_time': 276,
#    'first_sc_id': '7fce88e4-0d64-4a14-8724-0501a38b70a9'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 101,
#    'end_time': 109,
#    'first_sc_id': 'f2dbfc50-7d0a-4d08-b102-e9d41a5b4359'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 260,
#    'end_time': 262,
#    'first_sc_id': '14a80378-11f5-4c51-8ca4-39eb355ac257'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 44,
#    'end_time': 47,
#    'first_sc_id': 'fa87254e-ad31-4826-915c-e13d0c587a0f'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 270,
#    'end_time': 278,
#    'first_sc_id': '1f66fabd-c367-49ca-85e8-8986b07114e1'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 257,
#    'end_time': 264,
#    'first_sc_id': '9895910e-7925-40e4-9d47-65a39bbf92fd'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 210,
#    'end_time': 220,
#    'first_sc_id': 'ac8ec343-14a9-461c-b4ce-e7298a6bfa14'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 259,
#    'end_time': 266,
#    'first_sc_id': '6e1f7b3d-0308-417b-8196-aba62590bc70'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 236,
#    'end_time': 238,
#    'first_sc_id': '6f48ff23-0042-4677-b24f-b355c3cfabca'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 67,
#    'end_time': 70,
#    'first_sc_id': '1d65038d-7aa0-4d97-bef3-fad6af204074'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 130,
#    'end_time': 134,
#    'first_sc_id': '534f6b38-3f5f-4944-a898-637c49fa5ad5'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 265,
#    'end_time': 272,
#    'first_sc_id': '7683d513-4252-4ca2-9510-d34c1db63aee'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 254,
#    'end_time': 259,
#    'first_sc_id': '0646f503-78ab-42fd-af0d-d8960c3127ab'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 278,
#    'end_time': 281,
#    'first_sc_id': '505d950e-507a-4258-836f-821623056368'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 170,
#    'end_time': 176,
#    'first_sc_id': 'e00a0746-cd0e-4247-8c1a-33c154ab4508'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 159,
#    'end_time': 167,
#    'first_sc_id': '18577efd-7074-4cbe-a3f7-e36ab1d73539'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 68,
#    'end_time': 70,
#    'first_sc_id': '5ff9999d-703a-475d-b6ae-57a63df0e0a3'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 54,
#    'end_time': 59,
#    'first_sc_id': 'b23b4fb7-19e4-440d-bd99-11fd3afb72bc'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 112,
#    'end_time': 114,
#    'first_sc_id': 'f0ac2fe5-e97d-444c-8ffb-2e93d3ed662a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 188,
#    'end_time': 195,
#    'first_sc_id': '9c700380-4ace-4530-b9b9-3580905692c3'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 91,
#    'end_time': 100,
#    'first_sc_id': '37d4aa49-58c8-4aef-ad72-b9924bdfafe0'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 61,
#    'end_time': 68,
#    'first_sc_id': 'eb5ca5cd-db17-469b-a872-f2b5bc2e9af9'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 10,
#    'end_time': 23,
#    'first_sc_id': '9267a622-7ac5-4e02-9299-03694661b015'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 270,
#    'end_time': 276,
#    'first_sc_id': 'a2564719-de5e-4822-a21c-f4634a5b58e0'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 36,
#    'end_time': 38,
#    'first_sc_id': '91df9bd7-c416-4164-9cd8-ebea84d842a5'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 167,
#    'end_time': 170,
#    'first_sc_id': 'b992e89d-253b-439a-9743-a33a37c7b7a2'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 194,
#    'end_time': 198,
#    'first_sc_id': '448903f8-e238-467d-81ed-ca16a68299ee'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 268,
#    'end_time': 275,
#    'first_sc_id': 'dd8e3772-f101-4a5d-9039-8c9ecd2fab63'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 269,
#    'end_time': 273,
#    'first_sc_id': '1f0eec6e-ea27-4f46-96c2-a8ba6127c818'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 195,
#    'end_time': 200,
#    'first_sc_id': '60df5f76-4160-4bf0-8af8-f8051692df8b'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 231,
#    'end_time': 239,
#    'first_sc_id': '16b8c24c-9e34-43ed-aa7d-65c2808cba36'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 128,
#    'end_time': 132,
#    'first_sc_id': 'be6c3502-6a35-4fc7-89e8-e04217f6ce4f'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 255,
#    'end_time': 264,
#    'first_sc_id': 'ced30d52-c689-462a-9bd9-264ade2df347'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 192,
#    'end_time': 197,
#    'first_sc_id': 'f12f561b-edb7-492e-8625-2e79652fc13b'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 121,
#    'end_time': 125,
#    'first_sc_id': '0a633042-7c58-4c69-9a46-bcb38de718a3'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 175,
#    'end_time': 186,
#    'first_sc_id': '186b8b33-8ab1-4bfc-a5a3-b76b3c4665bb'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 203,
#    'end_time': 207,
#    'first_sc_id': '9b319a88-f439-4497-9a96-d7d807ce30bc'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 263,
#    'end_time': 265,
#    'first_sc_id': 'f394bb0b-4b8b-4e7e-9a6f-5c96b3795d2d'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 39,
#    'end_time': 43,
#    'first_sc_id': '064e22fa-b595-4d2e-a492-74b28f61cb17'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 192,
#    'end_time': 198,
# ...
#    'start_time': 131,
#    'end_time': 135,
#    'first_sc_id': '077d57ae-55e0-44ca-aad7-f99a051f4ee2'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 186,
#    'end_time': 196,
#    'first_sc_id': 'db3721cb-2370-4d8d-86cd-5ea778399da2'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 92,
#    'end_time': 94,
#    'first_sc_id': 'd514f945-d3c3-4163-8edd-e4ca32e83d44'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 67,
#    'end_time': 71,
#    'first_sc_id': '1d65038d-7aa0-4d97-bef3-fad6af204074'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 203,
#    'end_time': 210,
#    'first_sc_id': 'a0c715e9-a0b2-44fb-b3d2-d7942f6a4bc9'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 226,
#    'end_time': 229,
#    'first_sc_id': 'adf0a277-d440-49c9-b1a2-6c04c2c8c3b1'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 194,
#    'end_time': 200,
#    'first_sc_id': 'b73d7ab1-9f92-4ad1-a7ed-75d164af8ef0'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 16,
#    'end_time': 24,
#    'first_sc_id': 'f298779a-5dc3-45a9-81ec-f58ba8fbf741'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 188,
#    'end_time': 194,
#    'first_sc_id': '69523293-66a7-4363-b5ad-81e553d0d566'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 196,
#    'end_time': 201,
#    'first_sc_id': '2d8319fe-f218-4c81-b133-7c448af017c6'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 256,
#    'end_time': 263,
#    'first_sc_id': '33092016-5232-47fe-813c-2ee92b0d1c4f'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 174,
#    'end_time': 176,
#    'first_sc_id': 'c4084609-ffcd-4842-9687-2cdcf4dc743f'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 0,
#    'end_time': 21,
#    'first_sc_id': '193ec11c-59eb-4219-afec-d8f3dc629250'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 246,
#    'end_time': 254,
#    'first_sc_id': '47032bcf-967c-412e-9908-bd2be3fc7dae'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 272,
#    'end_time': 278,
#    'first_sc_id': 'cc84ceb5-2d06-4773-a46b-620d01e464c0'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 108,
#    'end_time': 110,
#    'first_sc_id': 'bdd7b83a-ccab-4f95-ad99-12c057d2c308'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 166,
#    'end_time': 176,
#    'first_sc_id': '5f3b2bcd-abd5-41cc-b5f8-c04fe0b149b1'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 241,
#    'end_time': 246,
#    'first_sc_id': '114934d5-cd20-4d4c-98fc-8cafaec5831e'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 169,
#    'end_time': 174,
#    'first_sc_id': 'e9f3ccd3-191b-48d4-8b89-af0671dc28b0'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 146,
#    'end_time': 157,
#    'first_sc_id': '7034ad07-0b1a-4982-8fbf-6655b200f7dc'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 277,
#    'end_time': 284,
#    'first_sc_id': '87a1d78f-dfd5-4562-a029-7b70ee812b68'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 240,
#    'end_time': 256,
#    'first_sc_id': '643e09a6-5064-4000-af5d-917727026b41'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 70,
#    'end_time': 73,
#    'first_sc_id': '8fd875de-f7df-481e-927d-6a118bf38a62'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 256,
#    'end_time': 261,
#    'first_sc_id': 'eea34caf-863e-46b7-a1db-2f61017eebdb'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 5,
#    'end_time': 11,
#    'first_sc_id': '01f8d97c-6ebe-405a-abe2-e3a5676bb389'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 269,
#    'end_time': 274,
#    'first_sc_id': 'e83fc5b9-c2b1-424b-a3ae-d7488cefa927'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 0,
#    'end_time': 2,
#    'first_sc_id': '68e9147a-4139-4580-ada1-b88e6a0efa74'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 203,
#    'end_time': 213,
#    'first_sc_id': '15034577-7be6-4692-ac3b-48e5cea81966'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 171,
#    'end_time': 179,
#    'first_sc_id': '4b984e9a-7af0-4725-936c-58fd8292bfaf'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 2,
#    'end_time': 8,
#    'first_sc_id': 'f91be954-d2bf-47a4-9c50-135adb7081a2'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 79,
#    'end_time': 88,
#    'first_sc_id': '51a33326-24d9-485c-b3b6-1d1c2b34235d'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 183,
#    'end_time': 191,
#    'first_sc_id': 'cca2497c-3793-4b17-8430-446228465034'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 227,
#    'end_time': 232,
#    'first_sc_id': '9a4b76f2-2c6e-43cf-b6a6-93f52f8a03b4'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 64,
#    'end_time': 71,
#    'first_sc_id': 'a59fd6a8-8e12-4ee7-8d96-8e5f317e079c'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 245,
#    'end_time': 247,
#    'first_sc_id': '76938268-257c-47b8-8d32-73fa11ba6b4a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 253,
#    'end_time': 257,
#    'first_sc_id': 'f2c2293c-979d-4730-912f-23b0d3a45326'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 112,
#    'end_time': 115,
#    'first_sc_id': 'f0ac2fe5-e97d-444c-8ffb-2e93d3ed662a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 0,
#    'end_time': 8,
#    'first_sc_id': '013fbbb7-4130-423f-91ee-5de799044853'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 269,
#    'end_time': 274,
#    'first_sc_id': 'e83fc5b9-c2b1-424b-a3ae-d7488cefa927'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 21,
#    'end_time': 23,
#    'first_sc_id': '1caa73e5-8dac-4e88-ac2f-881bca57d6aa'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 198,
#    'end_time': 202,
#    'first_sc_id': '67ef7223-acad-46c2-9097-35c7d17b0779'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 242,
#    'end_time': 246,
#    'first_sc_id': 'ace61c90-a970-49b4-8368-151a740ab91c'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 272,
#    'end_time': 280,
#    'first_sc_id': '9105442b-9a74-4572-b23a-04ab0c7e4eb8'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 27,
#    'end_time': 31,
#    'first_sc_id': '9cc90041-fa19-489b-8b36-1276f2e80118'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 86,
#    'end_time': 94,
#    'first_sc_id': 'ccf21218-6aa0-4fbb-81a8-559a60437d71'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 195,
#    'end_time': 199,
#    'first_sc_id': '0a59f366-6946-4517-99c9-9bbf47f44e52'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 5,
#    'end_time': 16,
#    'first_sc_id': '01f8d97c-6ebe-405a-abe2-e3a5676bb389'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 272,
#    'end_time': 275,
#    'first_sc_id': '1287f1b9-303b-4c0f-aad6-a33de4129198'},
#   {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_normal/C0.5^4'),
#    'start_time': 133,
#    'end_time': 139,
#    'first_sc_id': 'bce05db8-5461-4d0e-a1dd-4b5b7f01ab4e'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 81,
#    'end_time': 88,
#    'first_sc_id': 'd2155d29-0809-43dc-a6b8-35ff619fcff8'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 176,
#    'end_time': 185,
#    'first_sc_id': '06b2dbd5-62ca-4547-b4b8-f4c8aeb737f2'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 220,
#    'end_time': 223,
#    'first_sc_id': '8b4f54fc-164e-495f-8ba5-db5829e92310'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 42,
#    'end_time': 55,
#    'first_sc_id': 'eded9fd7-d036-42b3-b1a6-84888b39b02d'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 262,
#    'end_time': 268,
#    'first_sc_id': 'a83e8c74-082b-4f35-b244-0fdfb1d2721a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 21,
#    'end_time': 30,
#    'first_sc_id': '1efd2205-30a1-425a-8ad2-72e5096814b7'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 5,
#    'end_time': 15,
#    'first_sc_id': '01f8d97c-6ebe-405a-abe2-e3a5676bb389'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 92,
#    'end_time': 94,
#    'first_sc_id': '4b1aa3e6-93c0-4d2d-8d77-e6300bcec65a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 279,
#    'end_time': 286,
#    'first_sc_id': '1eb0ee60-290b-4436-899c-fccb8fe149b5'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 204,
#    'end_time': 207,
#    'first_sc_id': 'e3f2f0c5-ed48-4aca-b9db-c52ce4f8d2b0'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 245,
#    'end_time': 247,
#    'first_sc_id': '9f9d1043-545e-4a67-b25c-0bf6f014492a'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 244,
#    'end_time': 247,
#    'first_sc_id': '6b43b731-5387-4fad-a98b-6c526420806d'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 281,
#    'end_time': 283,
#    'first_sc_id': '1a6b4ac3-00f1-4442-8910-222223274dc2'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 55,
#    'end_time': 58,
#    'first_sc_id': 'eaed7480-3804-4ce8-be70-31187ea2ab57'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 104,
#    'end_time': 112,
#    'first_sc_id': '4efb06f6-32d9-4280-9170-321ce349db12'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 268,
#    'end_time': 272,
#    'first_sc_id': '9b083597-f59f-4bfe-aa3a-53578cbbf7ed'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 250,
#    'end_time': 253,
#    'first_sc_id': 'fa7681d7-c7c8-43ff-a219-196616b379e8'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 272,
#    'end_time': 276,
#    'first_sc_id': '1287f1b9-303b-4c0f-aad6-a33de4129198'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 30,
#    'end_time': 36,
#    'first_sc_id': 'c8cd6112-9d33-4d1b-85b4-7fe7218fa1b3'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 275,
#    'end_time': 277,
#    'first_sc_id': 'f8295f48-2933-4671-9715-8480ddb2a555'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 155,
#    'end_time': 159,
#    'first_sc_id': '4eb6508f-3040-46e9-a25f-5b3ae1c16a5d'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 17,
#    'end_time': 21,
#    'first_sc_id': '60f28a95-3640-46a9-80e0-62692b5f6c91'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 123,
#    'end_time': 127,
#    'first_sc_id': 'b2ab3e81-1a07-4806-a385-b7105b468fec'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 203,
#    'end_time': 210,
#    'first_sc_id': 'b2fd350b-fc17-4b73-853b-aff2f59c1746'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 10,
#    'end_time': 18,
#    'first_sc_id': 'f36267fb-af9b-4039-8f7e-08887e575794'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 287,
#    'end_time': 289,
#    'first_sc_id': 'be977a59-fae8-4da1-9bf0-4d1c1cec8c24'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 112,
#    'end_time': 120,
#    'first_sc_id': '76c255db-6263-47d4-abfa-95d6b760b3d0'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 226,
#    'end_time': 234,
#    'first_sc_id': '4edd1d2d-9f72-4553-8698-b8fe834d1344'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 257,
#    'end_time': 261,
#    'first_sc_id': '95195d1f-f149-406b-80b2-d85e7c3d8dae'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 166,
#    'end_time': 168,
#    'first_sc_id': '81e37bce-9ec5-411c-8b75-9b4b3f4b9f6b'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 172,
#    'end_time': 175,
#    'first_sc_id': 'fb852af1-c27a-420a-a423-33faa5ca5941'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 14,
#    'end_time': 17,
#    'first_sc_id': '20159dc9-ea12-4d96-8424-ebf8e522a2b4'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 278,
#    'end_time': 280,
#    'first_sc_id': 'd0d65eb3-6fd8-4e56-975f-a2341f1683b2'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 256,
#    'end_time': 262,
#    'first_sc_id': '47409817-7d78-497f-942b-706b1d8e7110'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 182,
#    'end_time': 197,
#    'first_sc_id': 'c7586124-8f0a-40f8-bf30-c29bd5cf43a1'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 197,
#    'end_time': 208,
#    'first_sc_id': '6eb2ba73-badf-400d-a2b0-2800c03a1378'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 269,
#    'end_time': 274,
#    'first_sc_id': '5d12acef-ded7-4356-8fc6-b9cbde015072'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 248,
#    'end_time': 265,
#    'first_sc_id': '60e7d3a1-a02b-4458-a970-ced4e0b9b241'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 269,
#    'end_time': 275,
#    'first_sc_id': '9d3b3d94-9d82-4b88-8e7b-2c59e78bbeaa'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY16/single_cells.json',
#    'start_time': 199,
#    'end_time': 204,
#    'first_sc_id': '3b36101f-137c-474b-8b8d-fc1a145946bb'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 268,
#    'end_time': 270,
#    'first_sc_id': '1453b6ca-f7b6-4007-aba6-9fe9792a9f82'},
#   {'src_dir': './datasets/test_scs_EBSS_starvation/XY1/single_cells.json',
#    'start_time': 248,
#    'end_time': 252,
#    'first_sc_id': '98b790d5-13e9-411b-8c79-7a3e4b2962fb'},
#   ...]}

# %%
import copy
from copy import deepcopy

def modify_class2sample_extra_info(class2sample_extra_info: Dict[str, List[Dict]], mitosis_traj_type, copy=True):
    for cls in class2sample_extra_info:
        for i, _info in enumerate(class2sample_extra_info[cls]):
            if copy:
                _info = dict(_info)
            _info["mitosis_traj_type"] = mitosis_traj_type
            class2sample_extra_info[cls][i] = _info
    

modify_class2sample_extra_info(train_class2sample_extra_info, "full")
modify_class2sample_extra_info(test_class2sample_extra_info, "full")

if INCLUDE_ALL:
    # Extra caution: be careful drop_div related copy by refernce syntax stuff...
    train_drop_div_class2samples = drop_multiple_cell_frames_in_samples(train_class2samples)
    train_drop_div_class2extra_info = {cls: list(train_class2sample_extra_info[cls]) for cls in train_class2sample_extra_info.keys()}
    modify_class2sample_extra_info(train_drop_div_class2extra_info, "drop_div")

    test_drop_div_class2samples = drop_multiple_cell_frames_in_samples(test_class2samples)
    test_drop_div_class2extra_info = {cls: list(test_class2sample_extra_info[cls]) for cls in test_class2sample_extra_info.keys()}
    modify_class2sample_extra_info(test_drop_div_class2extra_info, "drop_div")

    train_st_class2samples, train_st_class2sample_extra_info = make_one_cell_per_timeframe_for_class2samples(train_class2samples, train_class2sample_extra_info)
    test_st_class2samples, test_st_class2sample_extra_info = make_one_cell_per_timeframe_for_class2samples(test_class2samples, test_class2sample_extra_info)
    modify_class2sample_extra_info(train_st_class2sample_extra_info, "st")
    modify_class2sample_extra_info(test_st_class2sample_extra_info, "st")

    # check st info and sample length are the same
    assert len(train_st_class2samples["mitosis"]) == len(train_st_class2sample_extra_info["mitosis"])
    assert len(train_st_class2samples["normal"]) == len(train_st_class2sample_extra_info["normal"])

    # check drop-div info and sample length are the same
    assert len(train_drop_div_class2samples["mitosis"]) == len(train_drop_div_class2extra_info["mitosis"])
    assert len(train_drop_div_class2samples["normal"]) == len(train_drop_div_class2extra_info["normal"])

    for cls in train_drop_div_class2samples:
        assert len(train_drop_div_class2extra_info[cls]) == len(train_drop_div_class2samples[cls])
        
    for cls in train_class2samples:
        print("cls:", cls, "len(train_class2samples[cls]):", len(train_class2samples[cls]), "len(train_class2sample_extra_info[cls]):", len(train_class2sample_extra_info[cls]))
        assert len(train_class2samples[cls]) == len(train_class2sample_extra_info[cls]), \
            f"length of train_class2samples[{cls}] != length of train_class2sample_extra_info[{cls}], {len(train_class2samples[cls])} != {len(train_class2sample_extra_info[cls])}"
        
        assert len(train_st_class2sample_extra_info[cls]) == len(train_st_class2samples[cls]), f"flag1: {cls}"
        train_class2samples[cls].extend(train_st_class2samples[cls])
        train_class2sample_extra_info[cls].extend(train_st_class2sample_extra_info[cls])
        assert len(train_class2samples[cls]) == len(train_class2sample_extra_info[cls]), \
            f"length of train_class2samples[{cls}] != length of train_class2sample_extra_info[{cls}], {len(train_class2samples[cls])} != {len(train_class2sample_extra_info[cls])}"
        
        assert len(train_drop_div_class2extra_info[cls]) == len(train_drop_div_class2samples[cls]), f"flag2: {cls}, {len(train_drop_div_class2extra_info[cls])} != {len(train_drop_div_class2samples[cls])}"
        train_class2samples[cls].extend(train_drop_div_class2samples[cls])
        train_class2sample_extra_info[cls].extend(train_drop_div_class2extra_info[cls])
        # print("cls:", cls, "len(train_class2samples[cls]):", len(train_class2samples[cls]), "len(train_class2sample_extra_info[cls]):", len(train_class2sample_extra_info[cls]))

        test_class2samples[cls].extend(test_st_class2samples[cls])
        test_class2sample_extra_info[cls].extend(test_st_class2sample_extra_info[cls])

        test_class2samples[cls].extend(test_drop_div_class2samples[cls])
        test_class2sample_extra_info[cls].extend(test_drop_div_class2extra_info[cls])
# Out:
# cls: mitosis len(train_class2samples[cls]): 157 len(train_class2sample_extra_info[cls]): 157
# cls: apoptosis len(train_class2samples[cls]): 0 len(train_class2sample_extra_info[cls]): 0
# cls: normal len(train_class2samples[cls]): 1592 len(train_class2sample_extra_info[cls]): 1592

# %%
for key, val in train_class2samples.items():
    assert len(train_class2samples[key]) == len(train_class2sample_extra_info[key]), f"key: {key}, len(val): {len(val)}, len(train_class2sample_extra_info[key]): {len(train_class2sample_extra_info[key])}"

# %%
train_class2sample_extra_info["mitosis"]
# Out:
# [{'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 106,
#   'end_time': 118,
#   'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 109,
#   'end_time': 118,
#   'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 159,
#   'end_time': 183,
#   'first_sc_id': 'b4ac268b-b9bb-4b83-bd5a-858c9f3af094',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 121,
#   'end_time': 136,
#   'first_sc_id': 'a0dbfe2b-c48c-4bf4-b8d2-760f4495de1a',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 173,
#   'end_time': 184,
#   'first_sc_id': '999c92cd-7c3c-4b84-a8b0-1acf03215b01',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#   'start_time': 155,
#   'end_time': 168,
#   'first_sc_id': '2c92a009-46a1-4aae-8930-d113c754bac4',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 260,
#   'end_time': 277,
#   'first_sc_id': '9fe54c26-45a2-42af-b9da-32f4c9909e40',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 273,
#   'end_time': 289,
#   'first_sc_id': '02c376bf-5f23-470d-94d0-3513139a1164',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#   'start_time': 84,
#   'end_time': 96,
#   'first_sc_id': '559d0a8d-3186-4392-9d1e-f936fdd6510f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 243,
#   'end_time': 256,
#   'first_sc_id': 'f36b598c-f7e0-48bb-b6bb-a90f7be0a421',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 55,
#   'end_time': 62,
#   'first_sc_id': '456a5f3d-f1bb-483e-ad12-103346a6ca3d',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 224,
#   'end_time': 235,
#   'first_sc_id': '07acaf1f-b081-402d-8b12-4c33545a959f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 46,
#   'end_time': 58,
#   'first_sc_id': '4d662ffd-06be-46f2-a8bd-21bd26c08b79',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 151,
#   'end_time': 159,
#   'first_sc_id': 'beceb2c6-b2bb-49d4-98ba-710b158e45e2',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#   'start_time': 175,
#   'end_time': 183,
#   'first_sc_id': 'c92fa4a6-c2fc-4b1b-9a62-b1edfc1a98b0',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 154,
#   'end_time': 163,
#   'first_sc_id': 'ca123ef6-df57-4a94-a67c-6193f54513c8',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 139,
#   'end_time': 148,
#   'first_sc_id': 'e14f1a39-f0fc-44e7-852b-8c42ffef0998',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#   'start_time': 272,
#   'end_time': 291,
#   'first_sc_id': '24a16a9c-4cef-4f2e-9e19-7803b167c98e',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 139,
#   'end_time': 148,
#   'first_sc_id': 'e14f1a39-f0fc-44e7-852b-8c42ffef0998',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 66,
#   'end_time': 79,
#   'first_sc_id': 'ba6ddc87-1a93-4d6c-86be-57e8e561bd87',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 127,
#   'end_time': 136,
#   'first_sc_id': '5a688a30-c08f-4588-9e7e-cd5d6fb460a9',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 23,
#   'end_time': 35,
#   'first_sc_id': '4c750589-6b92-4e52-a1be-2bcbeed90f7e',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 235,
#   'end_time': 246,
#   'first_sc_id': '9f0cfbca-a1ec-47b2-a1c2-44ec6cae6202',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 158,
#   'end_time': 171,
#   'first_sc_id': '8b4f95ef-7bed-4a47-b68f-bd54880f7ccb',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 192,
#   'end_time': 204,
#   'first_sc_id': '42125368-8092-48bb-add7-3613a67a22d3',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#   'start_time': 19,
#   'end_time': 26,
#   'first_sc_id': '4f32e9eb-338c-474c-ba51-3626d7fb326f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 189,
#   'end_time': 197,
#   'first_sc_id': '9be5efae-94d4-4242-ae76-3624be7ae695',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 127,
#   'end_time': 137,
#   'first_sc_id': '13775974-804f-4e18-b56d-0bbf4302f603',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 2,
#   'end_time': 15,
#   'first_sc_id': 'de2f64db-23c7-416b-bb09-fcf9197d9e2d',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 94,
#   'end_time': 105,
#   'first_sc_id': '057a319d-093f-4fc0-9ecd-47b7446417b6',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 196,
#   'end_time': 205,
#   'first_sc_id': '9935c28b-11ce-44ca-9077-55d19c4938a6',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.5^4'),
#   'start_time': 146,
#   'end_time': 154,
#   'first_sc_id': '0ec6cfd6-82c1-4746-a8be-4bd6d399b407',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#   'start_time': 252,
#   'end_time': 265,
#   'first_sc_id': '5289f931-752e-4934-ab6a-10ebc91a5159',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 38,
#   'end_time': 49,
#   'first_sc_id': '58d3936b-3cd2-410d-958c-e0289c3167a5',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 125,
#   'end_time': 134,
#   'first_sc_id': '86c31717-f4b6-4f80-a081-27217a967bb5',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 272,
#   'end_time': 282,
#   'first_sc_id': 'f980f6de-1c28-4dfc-83fe-3dadfca0aa21',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 203,
#   'end_time': 216,
#   'first_sc_id': '983bcd65-dbfe-48d2-9949-a904d93024e3',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 156,
#   'end_time': 163,
#   'first_sc_id': '13b3df9b-90c8-44f7-85e9-6860bf26573f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 126,
#   'end_time': 137,
#   'first_sc_id': '086ae042-97fe-4c5f-bc36-feff453388d7',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#   'start_time': 30,
#   'end_time': 40,
#   'first_sc_id': '5643ff85-8a4e-4619-9afd-721ad8d7e551',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 188,
#   'end_time': 200,
#   'first_sc_id': '11fd4ca5-4188-41d7-a6eb-a0f0e92b8798',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#   'start_time': 117,
#   'end_time': 128,
#   'first_sc_id': 'cf01a3a3-cedd-4007-a264-889076755938',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 224,
#   'end_time': 235,
#   'first_sc_id': '07acaf1f-b081-402d-8b12-4c33545a959f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 144,
#   'end_time': 152,
#   'first_sc_id': '1570f176-15d2-4e63-9bed-d7f3b06f8df1',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 138,
#   'end_time': 148,
#   'first_sc_id': 'd26a92f6-d612-46da-bcb6-e7b2cf4d113d',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 234,
#   'end_time': 246,
#   'first_sc_id': '7e96f0a0-edd8-4390-b100-2d3425ed0808',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#   'start_time': 148,
#   'end_time': 162,
#   'first_sc_id': 'e7d3511c-53e9-4632-b41d-dd61620399b4',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 6,
#   'end_time': 19,
#   'first_sc_id': 'fd3cf52a-0a4e-44bb-86b7-b58e31cf2de2',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 114,
#   'first_sc_id': 'd89799b1-3ff5-42cc-ad50-f5654428ac38',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 240,
#   'end_time': 251,
#   'first_sc_id': '1a548f3a-a903-4e73-88c9-a2c1669e1525',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 171,
#   'end_time': 182,
#   'first_sc_id': 'de01d271-de59-4488-a526-f5c6f58e5eec',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 109,
#   'end_time': 119,
#   'first_sc_id': '0fa899ed-db36-4bc0-a49b-62a46e580b2e',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 51,
#   'end_time': 67,
#   'first_sc_id': '3e6cbc6d-a8ad-4d51-bc64-0e49e4107f7c',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 49,
#   'end_time': 60,
#   'first_sc_id': 'b1a8a6ab-4a77-4f06-8358-fe8dccf5ab19',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#   'start_time': 278,
#   'end_time': 292,
#   'first_sc_id': '16385ded-c2c7-4051-8eff-7428ff94374b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 274,
#   'end_time': 288,
#   'first_sc_id': '22f7030c-e635-466e-b89d-8f829194a3ad',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 81,
#   'end_time': 94,
#   'first_sc_id': 'bbe9b05a-fb31-470f-99b1-1c1189a69f00',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 156,
#   'end_time': 165,
#   'first_sc_id': 'ed3c97de-c03c-4f20-9450-ba347f735b1f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 94,
#   'end_time': 106,
#   'first_sc_id': 'be628c2a-304e-4ef7-bd28-c5af90eca5c7',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 131,
#   'end_time': 144,
#   'first_sc_id': '064b2a8a-7390-42ee-ae4f-d89c94506985',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 169,
#   'end_time': 180,
#   'first_sc_id': '6fcd509f-fddc-4fb9-81f6-f00faf2a8b2f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 74,
#   'end_time': 83,
#   'first_sc_id': '61a0958d-7e26-4418-a9a5-05d43da69283',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 100,
#   'end_time': 111,
#   'first_sc_id': '96f34ead-1445-4664-9dd9-abd3ce77907a',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#   'start_time': 64,
#   'end_time': 70,
#   'first_sc_id': '1282868e-4855-4d1c-9e1a-400b794a92e6',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 102,
#   'end_time': 113,
#   'first_sc_id': '86a6962a-7ec5-429f-87f4-27d1775eae7b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#   'start_time': 75,
#   'end_time': 87,
#   'first_sc_id': 'dbdc419d-3269-4045-8b44-d9cc144ce407',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 274,
#   'end_time': 283,
#   'first_sc_id': 'd15196f3-abe6-41f0-a2b5-2b7ca2643da2',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^3'),
#   'start_time': 139,
#   'end_time': 150,
#   'first_sc_id': '52038fa9-d237-44a4-a293-020feb739fe3',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 276,
#   'end_time': 289,
#   'first_sc_id': 'd4e080fe-a285-4746-80c3-8b49c5e03680',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 68,
#   'end_time': 77,
#   'first_sc_id': '6d8a6cc8-1afe-4c1f-bebd-b19ad51e40cb',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 215,
#   'end_time': 225,
#   'first_sc_id': '305ae37c-d948-4953-b18e-45435f789b2a',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 173,
#   'end_time': 183,
#   'first_sc_id': 'e60e4ee1-c76d-4108-918e-8e2148513f39',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 274,
#   'end_time': 283,
#   'first_sc_id': 'b8d90813-8b7d-460d-ab7f-2188f338fd04',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 85,
#   'end_time': 99,
#   'first_sc_id': '5c20bd80-4fdb-47ec-bfaf-107275b52388',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 56,
#   'end_time': 68,
#   'first_sc_id': '68b6a5e9-67af-4bbb-9e2a-37eec1ed771f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 8,
#   'end_time': 20,
#   'first_sc_id': 'bca30362-81d7-4af2-809f-8289272c0326',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 57,
#   'end_time': 67,
#   'first_sc_id': 'a9c5f6bd-babc-42cc-a32a-c6c72860415b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 277,
#   'end_time': 287,
#   'first_sc_id': '35fa9ff0-3996-479e-9921-4603be117c57',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#   'start_time': 165,
#   'end_time': 174,
#   'first_sc_id': 'a0e8263d-cc77-420c-b916-ab2fe3ef9947',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#   'start_time': 60,
#   'end_time': 69,
#   'first_sc_id': '49edeb21-c133-49b1-a741-98ccbae8af43',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 92,
#   'end_time': 104,
#   'first_sc_id': '9d939a81-2379-4a36-9137-61953125a145',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 53,
#   'end_time': 62,
#   'first_sc_id': '9e35fa64-8392-48d0-a788-c548c0793a39',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 77,
#   'end_time': 87,
#   'first_sc_id': '2c1833d6-109e-48e5-8028-3f57ccc0123a',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 50,
#   'end_time': 58,
#   'first_sc_id': '310226a1-5e47-4a0a-b53f-543e36743f56',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 146,
#   'end_time': 160,
#   'first_sc_id': '928d01d9-4383-4d3c-a199-c99eec4f29cb',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 170,
#   'end_time': 185,
#   'first_sc_id': '3da987ad-753f-486e-8bdb-c7fb67049808',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 241,
#   'end_time': 252,
#   'first_sc_id': '2855106b-9063-4e2f-b7ac-43d756729dbf',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 20,
#   'end_time': 30,
#   'first_sc_id': 'a1a8886c-c756-496e-b18e-feab7fd62c68',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#   'start_time': 47,
#   'end_time': 55,
#   'first_sc_id': 'd36bdf19-f8bb-4713-a667-c6828516f100',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 290,
#   'end_time': 301,
#   'first_sc_id': '41f77cef-ed1f-4b3c-8a59-3008f9f57f71',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 86,
#   'end_time': 95,
#   'first_sc_id': 'd75631bf-b955-49f2-80a9-3fd2fbfa7d20',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 105,
#   'end_time': 115,
#   'first_sc_id': '138ef752-af6d-491a-8ab8-420abc0d9a4b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#   'start_time': 74,
#   'end_time': 87,
#   'first_sc_id': '1ac75e2b-daf1-4285-a687-227783c811a5',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 92,
#   'end_time': 106,
#   'first_sc_id': '3b483c8c-cb71-42fe-b2e1-69257670f884',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 127,
#   'end_time': 135,
#   'first_sc_id': '0ae7ad67-fb29-4e5b-ab6a-7c91f05ebaf2',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 145,
#   'end_time': 159,
#   'first_sc_id': '38fb72df-d715-482f-875d-3241f6b8c751',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 117,
#   'end_time': 127,
#   'first_sc_id': '337534a0-2b25-4043-9390-575af44876d9',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 237,
#   'end_time': 248,
#   'first_sc_id': 'a7d0f1bc-3fd9-4518-b470-e30971b9acb4',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 287,
#   'end_time': 297,
#   'first_sc_id': '06962166-324f-476e-92ef-36d4a8ec92f7',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 248,
#   'end_time': 258,
#   'first_sc_id': '718998b6-72af-4a0d-a10d-4f013d6ffb60',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#   'start_time': 169,
#   'end_time': 179,
#   'first_sc_id': '15c99ebd-15ce-4467-860c-b5f1758577ba',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 137,
#   'end_time': 150,
#   'first_sc_id': 'fd488fe9-44ff-415b-9590-010be5ed9a02',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 177,
#   'end_time': 186,
#   'first_sc_id': '55a1156a-f85e-4a6a-a7e1-fdc18bd4697f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 17,
#   'end_time': 26,
#   'first_sc_id': 'd917e087-6ef7-430b-83fe-ca96be01747c',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 42,
#   'end_time': 52,
#   'first_sc_id': '45670ea4-3779-4fa1-b6c3-2d6164b425d9',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#   'start_time': 194,
#   'end_time': 206,
#   'first_sc_id': 'f3769191-0a03-4688-931f-e3cfb176325b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 254,
#   'end_time': 270,
#   'first_sc_id': 'd5bf6f73-80f0-4cf3-803e-2fef0fa2bec0',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 280,
#   'end_time': 290,
#   'first_sc_id': '5a17b096-fcdd-474b-8364-12630fe95d82',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY8/annotations'),
#   'start_time': 2,
#   'end_time': 12,
#   'first_sc_id': 'b469d334-c05b-43ab-a4f0-3410fafffc10',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 22,
#   'end_time': 33,
#   'first_sc_id': '99edddb4-6bbb-4f8c-aa62-b5588e9d9f63',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 22,
#   'end_time': 34,
#   'first_sc_id': 'cba0f157-6729-4b87-8e7d-0f22ac5db49f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 221,
#   'end_time': 232,
#   'first_sc_id': 'cd7c706c-9c67-4955-a50c-9ece316e01a3',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 110,
#   'end_time': 121,
#   'first_sc_id': '31b17d1d-f17c-458c-8cc2-51a05186b616',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 117,
#   'end_time': 126,
#   'first_sc_id': 'db7abf5d-484b-485d-83a3-462a47512e70',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 146,
#   'end_time': 155,
#   'first_sc_id': 'ff6d8d33-cc51-4eda-a416-ceeb50c01fb0',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 126,
#   'end_time': 138,
#   'first_sc_id': 'ee450fbc-e942-4498-adc1-743416d0ba0e',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY13/annotations'),
#   'start_time': 175,
#   'end_time': 190,
#   'first_sc_id': '31929807-b3a2-413f-a846-dfe9ef00dbff',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 239,
#   'end_time': 249,
#   'first_sc_id': '5fc754b1-e519-43d7-8f8b-abefb8f15036',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 125,
#   'end_time': 134,
#   'first_sc_id': '86c31717-f4b6-4f80-a081-27217a967bb5',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY6/annotations'),
#   'start_time': 237,
#   'end_time': 248,
#   'first_sc_id': '4eb85515-9d14-46c6-943c-ff674997524e',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 198,
#   'end_time': 207,
#   'first_sc_id': '109ef75a-1f0b-4e40-95d6-4e2a2fa53948',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 92,
#   'end_time': 104,
#   'first_sc_id': '9d939a81-2379-4a36-9137-61953125a145',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY5/annotations'),
#   'start_time': 125,
#   'end_time': 137,
#   'first_sc_id': '977f0875-6ecc-45f6-a53a-0bebe9687705',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 107,
#   'end_time': 118,
#   'first_sc_id': '8628ebbb-04fd-40ce-a839-03b20d50569b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 144,
#   'end_time': 153,
#   'first_sc_id': '40225d52-b35a-4317-969b-7f0461b1e892',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 109,
#   'end_time': 118,
#   'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 117,
#   'end_time': 127,
#   'first_sc_id': '4ae4e2c5-795c-4504-9e99-796adc43b44c',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 190,
#   'end_time': 205,
#   'first_sc_id': '417bfb8c-d841-454e-9226-8e80bd619a75',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 234,
#   'end_time': 247,
#   'first_sc_id': '0ba42739-94de-4a7e-b982-11c6c7575538',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 114,
#   'end_time': 125,
#   'first_sc_id': 'f1db5924-ec8d-49c1-a8e1-4bd1863cdf61',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 94,
#   'end_time': 106,
#   'first_sc_id': 'd27b838c-2d3c-4c86-8610-a631dfd89f95',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 153,
#   'end_time': 162,
#   'first_sc_id': 'dacc7ce2-0eb6-46da-a648-0f607a1a987b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 76,
#   'end_time': 95,
#   'first_sc_id': '3dc57e89-1035-431c-b23f-2fcea9cdf3bc',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 280,
#   'end_time': 290,
#   'first_sc_id': 'a654f191-8e47-47eb-a2aa-697c9d979ee1',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 173,
#   'end_time': 183,
#   'first_sc_id': '7f933c39-e3d4-4741-a6a0-f00020948a3b',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 141,
#   'end_time': 159,
#   'first_sc_id': '327e5534-1c65-4ba2-9e73-099124b69de4',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 156,
#   'end_time': 165,
#   'first_sc_id': 'ed3c97de-c03c-4f20-9450-ba347f735b1f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C10^4'),
#   'start_time': 37,
#   'end_time': 45,
#   'first_sc_id': 'b7bb10ea-e41d-419e-9e18-c10e1086af11',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY11/annotations'),
#   'start_time': 124,
#   'end_time': 132,
#   'first_sc_id': '7c9c56ba-575a-4182-8cf8-e99b3cd7d491',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 127,
#   'end_time': 136,
#   'first_sc_id': '5a688a30-c08f-4588-9e7e-cd5d6fb460a9',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 106,
#   'end_time': 118,
#   'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 214,
#   'end_time': 224,
#   'first_sc_id': 'af8a8cc6-8eb6-4897-95e3-d3c796602d31',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY9/annotations'),
#   'start_time': 121,
#   'end_time': 134,
#   'first_sc_id': '1a77ecd7-f531-4fd0-90e5-4f69e2c9ddcc',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 74,
#   'end_time': 83,
#   'first_sc_id': '61a0958d-7e26-4418-a9a5-05d43da69283',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY7/annotations'),
#   'start_time': 67,
#   'end_time': 78,
#   'first_sc_id': '4ac9dcf8-aff6-4728-bfe1-ee2b52d988c5',
#   'mitosis_traj_type': 'full'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 106,
#   'end_time': 118,
#   'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 106,
#   'end_time': 118,
#   'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 106,
#   'end_time': 118,
#   'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 106,
#   'end_time': 118,
#   'first_sc_id': '6d294019-276f-4636-88c2-c94f5871106f',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 258,
#   'end_time': 267,
#   'first_sc_id': '81aba36a-5344-49ba-9b0f-200441080359',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 82,
#   'end_time': 92,
#   'first_sc_id': '6edc7e99-3d45-499e-b3d2-ff2fe19390dc',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 98,
#   'end_time': 109,
#   'first_sc_id': '50956018-9cbd-4ca8-ad5b-04c10e3e4108',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 109,
#   'end_time': 118,
#   'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 109,
#   'end_time': 118,
#   'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 109,
#   'end_time': 118,
#   'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 109,
#   'end_time': 118,
#   'first_sc_id': 'e6b95f5e-4fd3-41fd-8a3c-cae8f9312a50',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
# ...
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY10/annotations'),
#   'start_time': 68,
#   'end_time': 81,
#   'first_sc_id': '98adaa06-d62b-4d4a-b5f2-735b0ae69ed8',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY16/annotations'),
#   'start_time': 227,
#   'end_time': 234,
#   'first_sc_id': 'd5d9001a-a55a-4f72-9532-b7f32700abfd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY4/annotations'),
#   'start_time': 209,
#   'end_time': 219,
#   'first_sc_id': '98014bd9-c942-4719-b1d9-b94568eeccdd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 77,
#   'end_time': 87,
#   'first_sc_id': '2c1833d6-109e-48e5-8028-3f57ccc0123a',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 77,
#   'end_time': 87,
#   'first_sc_id': '2c1833d6-109e-48e5-8028-3f57ccc0123a',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 77,
#   'end_time': 87,
#   'first_sc_id': '2c1833d6-109e-48e5-8028-3f57ccc0123a',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 77,
#   'end_time': 87,
#   'first_sc_id': '2c1833d6-109e-48e5-8028-3f57ccc0123a',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 104,
#   'end_time': 116,
#   'first_sc_id': '48e8e7ad-60aa-48d3-b043-fb0fb5caeff0',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('datasets/test_scs_EBSS_starvation/XY1/annotations'),
#   'start_time': 57,
#   'end_time': 64,
#   'first_sc_id': '171947ec-0dc3-4b2b-8f64-0cf544b2ec48',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 50,
#   'end_time': 58,
#   'first_sc_id': '310226a1-5e47-4a0a-b53f-543e36743f56',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 50,
#   'end_time': 58,
#   'first_sc_id': '310226a1-5e47-4a0a-b53f-543e36743f56',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 50,
#   'end_time': 58,
#   'first_sc_id': '310226a1-5e47-4a0a-b53f-543e36743f56',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/shiman_CXA_high_density/C0.75^4'),
#   'start_time': 50,
#   'end_time': 58,
#   'first_sc_id': '310226a1-5e47-4a0a-b53f-543e36743f56',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'st'},
#  {'src_dir': PosixPath('../datasets/mitosis-annotations-2023/Gaohan_tifs_CFP_A549-VIM_lessThan24hr_NoTreat_NA_YL_Ti2e_2022-10-19/XY12/annotations'),
#   'start_time': 127,
#   'end_time': 140,
#   'first_sc_id': 'c97554cb-bb6b-4fc4-b7af-a1369170babd',
#   'mitosis_traj_type': 'st'},
#  ...]

# %%
import importlib
import livecellx
import livecellx.core.sc_video_utils
importlib.reload(livecellx.core.sc_video_utils)

# padding_pixels = [20]

train_sample_info_df = livecellx.core.sc_video_utils.gen_class2sample_samples(
    train_class2samples,
    train_class2sample_extra_info,
    data_dir,
    class_labels,
    padding_pixels=padding_pixels,
    frame_types=frame_types,
    fps=fps,
    prefix="train",
)
test_sample_info_df = livecellx.core.sc_video_utils.gen_class2sample_samples(
    test_class2samples,
    test_class2sample_extra_info,
    data_dir,
    class_labels,
    padding_pixels=padding_pixels,
    frame_types=frame_types,
    fps=fps,
    prefix="test",
)
# Out:
# 100%|██████████| 1669/1669 [06:03<00:00,  4.59it/s]
# 100%|██████████| 1669/1669 [02:37<00:00, 10.62it/s]
# 100%|██████████| 1669/1669 [03:06<00:00,  8.97it/s]
# 100%|██████████| 1669/1669 [03:22<00:00,  8.26it/s]
# 100%|██████████| 1669/1669 [05:04<00:00,  5.48it/s]
# 100%|██████████| 1669/1669 [10:05<00:00,  2.76it/s]
# 100%|██████████| 1669/1669 [24:59<00:00,  1.11it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 4776/4776 [04:21<00:00, 18.27it/s]
# 100%|██████████| 4776/4776 [03:35<00:00, 22.18it/s]
# 100%|██████████| 4776/4776 [04:08<00:00, 19.23it/s]
# 100%|██████████| 4776/4776 [04:29<00:00, 17.73it/s]
# 100%|██████████| 4776/4776 [06:44<00:00, 11.82it/s]
# 100%|██████████| 4776/4776 [13:32<00:00,  5.88it/s]
# 100%|██████████| 4776/4776 [34:56<00:00,  2.28it/s]
# 100%|██████████| 365/365 [00:46<00:00,  7.88it/s]
# 100%|██████████| 365/365 [00:33<00:00, 10.98it/s]
# 100%|██████████| 365/365 [00:39<00:00,  9.28it/s]
# 100%|██████████| 365/365 [00:42<00:00,  8.51it/s]
# 100%|██████████| 365/365 [01:04<00:00,  5.63it/s]
# 100%|██████████| 365/365 [02:10<00:00,  2.79it/s]
# 100%|██████████| 365/365 [05:32<00:00,  1.10it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 1197/1197 [00:51<00:00, 23.15it/s]
# 100%|██████████| 1197/1197 [00:56<00:00, 21.20it/s]
# 100%|██████████| 1197/1197 [01:04<00:00, 18.60it/s]
# 100%|██████████| 1197/1197 [01:09<00:00, 17.15it/s]
# 100%|██████████| 1197/1197 [01:42<00:00, 11.69it/s]
# 100%|██████████| 1197/1197 [03:26<00:00,  5.79it/s]
# 100%|██████████| 1197/1197 [08:47<00:00,  2.27it/s]

# %%
train_sample_info_df[:2]
# Out:
#                                 path label_index padding_pixels frame_type  \
# 0  train_mitosis_0_raw_padding-1.mp4           0              1      video
# 1  train_mitosis_1_raw_padding-1.mp4           0              1      video
#
#                                              src_dir track_id start_time  \
# 0  datasets/test_scs_EBSS_starvation/XY16/annotat...       -1        106
# 1  datasets/test_scs_EBSS_starvation/XY1/annotations       -1        258
#
#   end_time                           first_sc_id mitosis_traj_type
# 0      118  6d294019-276f-4636-88c2-c94f5871106f              full
# 1      267  81aba36a-5344-49ba-9b0f-200441080359              full

# %%
train_sample_info_df.to_csv(
    data_dir / f"train_data.txt",
    index=False,
    header=True,
    sep=" ",
)
test_sample_info_df.to_csv(
    data_dir / f"test_data.txt",
    index=False,
    header=True,
    sep=" ",
)

# %%
train_sample_info_df = pd.read_csv(data_dir / f"train_data.txt", sep=" ")
test_sample_info_df = pd.read_csv(data_dir / f"test_data.txt", sep=" ")

mmaction_df_paths = []
for selected_frame_type in frame_types + ["all"]:
    train_df_path = data_dir / f"mmaction_train_data_{selected_frame_type}.txt"
    if selected_frame_type == "all":
        train_selected_frame_type_df = train_sample_info_df
    else:
        train_selected_frame_type_df = train_sample_info_df[train_sample_info_df["frame_type"] == selected_frame_type]
    train_selected_frame_type_df = train_selected_frame_type_df.reset_index(drop=True)
    train_selected_frame_type_df = train_selected_frame_type_df[["path", "label_index"]]
    train_selected_frame_type_df.to_csv(train_df_path, index=False, header=False, sep=" ")

    test_df_path = data_dir / f"mmaction_test_data_{selected_frame_type}.txt"

    if selected_frame_type == "all":
        test_selected_frame_type_df = test_sample_info_df
    else:
        test_selected_frame_type_df = test_sample_info_df[test_sample_info_df["frame_type"] == selected_frame_type]
    test_selected_frame_type_df = test_selected_frame_type_df[["path", "label_index"]]
    test_selected_frame_type_df = test_selected_frame_type_df.reset_index(drop=True)
    test_selected_frame_type_df.to_csv(test_df_path, index=False, header=False, sep=" ")

    mmaction_df_paths.append(train_df_path)
    mmaction_df_paths.append(test_df_path)

mmaction_df_paths
# # The follwing code generates v1-v7 test data. The issue is that some of test data shows up in train data, through different padding values.
# data_df_path = data_dir/'all_data.txt'
# sample_df = gen_samples_df(data_dir, class_labels, padding_pixels, frame_types, fps)
# sample_df.to_csv(data_df_path, index=False, header=False, sep=' ')
# for selected_frame_type in frame_types:
#     selected_frame_type_df = sample_df[sample_df["frame_type"] == selected_frame_type]
#     selected_frame_type_df = selected_frame_type_df.reset_index(drop=True)
#     train_df_path = data_dir/f'train_data_{selected_frame_type}.txt'
#     test_df_path = data_dir/f'test_data_{selected_frame_type}.txt'
#     train_df = selected_frame_type_df.sample(frac=0.8, random_state=0, replace=False)
#     test_df = selected_frame_type_df.drop(train_df.index, inplace=False)

#     # only keep the path and label_index columns
#     train_df = train_df[["path", "label_index"]]
#     test_df = test_df[["path", "label_index"]]

#     train_df.to_csv(train_df_path, index=False, header=False, sep=' ')
#     test_df.to_csv(test_df_path, index=False, header=False, sep=' ')
# Out:
# [PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_train_data_video.txt'),
#  PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_test_data_video.txt'),
#  PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_train_data_mask.txt'),
#  PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_test_data_mask.txt'),
#  PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_train_data_combined.txt'),
#  PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_test_data_combined.txt'),
#  PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_train_data_all.txt'),
#  PosixPath('notebook_results/mmaction_train_data_v14-inclusive/mmaction_test_data_all.txt')]

# %% [markdown]
# Check the videos

# %%
video_paths = list(Path(data_dir/'videos').glob('*.mp4'))
print("len(video_paths):", len(video_paths))
# Out:
# len(video_paths): 168147

# %% [markdown]
# Due to a `decord` package [issue](https://github.com/dmlc/decord/issues/150), to use mmaction2 we must check if the videos can be loaded by `decord` correctly.

# %%
import decord
decord.__version__
# Out:
# '0.6.0'

# %%
import decord
invalid_decord_paths = []
for path in tqdm(video_paths):
# for path in ["./notebook_results/train_normal_6_raw_padding-0.mp4"]:
# for path in ["./test_video_output.mp4"]:
    reader = decord.VideoReader(str(path))
    reader.seek(0)
    imgs = list()
    frame_inds = range(0, len(reader))
    for idx in frame_inds:
        reader.seek(idx)
        frame = reader.next()
        imgs.append(frame.asnumpy())
        frame = frame.asnumpy()

        num_channels = frame.shape[-1]
        if num_channels != 3:
            print("invalid video for decord (https://github.com/dmlc/decord/issues/150): ", path)
            invalid_decord_paths.append(path)
            break
        # fig, axes = plt.subplots(1, num_channels, figsize=(20, 10))
        # for i in range(num_channels):
        #     axes[i].imshow(frame[:, :, i])
        # plt.show()
    del reader
# Out:
#   1%|          | 1951/168147 [00:08<10:20, 267.64it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2304_raw_padding-1.mp4
#   6%|▋         | 10655/168147 [00:43<10:35, 247.71it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2304_mask_padding-1.mp4
#   7%|▋         | 12545/168147 [00:51<11:49, 219.46it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2652_raw_padding-1.mp4
#   9%|▊         | 14488/168147 [00:59<10:58, 233.37it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1060_combined_padding-1.mp4
#  12%|█▏        | 20677/168147 [01:25<10:18, 238.28it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_729_mask_padding-1.mp4
#  12%|█▏        | 20834/168147 [01:25<10:53, 225.31it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2148_raw_padding-1.mp4
#  13%|█▎        | 21622/168147 [01:29<09:42, 251.35it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1933_raw_padding-1.mp4
#  17%|█▋        | 28092/168147 [01:55<09:06, 256.33it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3740_combined_padding-1.mp4
#  18%|█▊        | 29953/168147 [02:03<10:15, 224.65it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2148_combined_padding-1.mp4
#  19%|█▊        | 31214/168147 [02:08<09:40, 235.76it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3199_mask_padding-1.mp4
#  21%|██        | 35308/168147 [02:25<08:36, 257.26it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3896_combined_padding-1.mp4
#  21%|██▏       | 35924/168147 [02:27<08:12, 268.61it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_4244_mask_padding-1.mp4
#  24%|██▍       | 40834/168147 [02:48<07:41, 275.66it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_556_mask_padding-1.mp4
#  26%|██▌       | 42919/168147 [02:56<07:52, 264.95it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3525_combined_padding-1.mp4
#  27%|██▋       | 45265/168147 [03:06<08:46, 233.38it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2652_combined_padding-1.mp4
#  28%|██▊       | 46616/168147 [03:11<09:25, 214.80it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_556_combined_padding-1.mp4
#  29%|██▉       | 49445/168147 [03:23<08:26, 234.28it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1607_raw_padding-1.mp4
#  33%|███▎      | 55783/168147 [03:49<06:50, 273.42it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3896_mask_padding-1.mp4
#  33%|███▎      | 55868/168147 [03:49<06:57, 268.91it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1413_combined_padding-1.mp4
#  40%|███▉      | 67167/168147 [04:35<06:48, 247.42it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1607_mask_padding-1.mp4
#  42%|████▏     | 71261/168147 [04:52<06:38, 242.87it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_1128_raw_padding-1.mp4
#  43%|████▎     | 72843/168147 [04:59<06:09, 257.90it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_556_raw_padding-1.mp4
#  45%|████▌     | 76096/168147 [05:12<06:09, 249.15it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_4244_raw_padding-1.mp4
#  48%|████▊     | 81253/168147 [05:33<05:09, 281.10it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2304_combined_padding-1.mp4
#  49%|████▉     | 83163/168147 [05:41<05:10, 273.86it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3005_mask_padding-1.mp4
#  50%|█████     | 84175/168147 [05:45<05:35, 250.28it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_15_combined_padding-1.mp4
#  50%|█████     | 84254/168147 [05:45<05:55, 235.81it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2652_mask_padding-1.mp4
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3525_mask_padding-1.mp4
#  51%|█████     | 85546/168147 [05:50<05:08, 267.71it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_341_mask_padding-1.mp4
#  51%|█████     | 86120/168147 [05:53<06:14, 218.90it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1060_mask_padding-1.mp4
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_2148_mask_padding-1.mp4
#  54%|█████▎    | 90356/168147 [06:11<04:43, 274.29it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_712_raw_padding-1.mp4
#  54%|█████▍    | 91516/168147 [06:15<05:03, 252.41it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1413_mask_padding-1.mp4
#  55%|█████▍    | 92461/168147 [06:19<06:03, 208.27it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1413_raw_padding-1.mp4
#  56%|█████▌    | 94404/168147 [06:27<05:35, 219.79it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_330_raw_padding-1.mp4
#  64%|██████▍   | 107377/168147 [07:20<04:07, 246.00it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3525_raw_padding-1.mp4
#  65%|██████▍   | 108489/168147 [07:25<03:45, 264.57it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1933_mask_padding-1.mp4
#  65%|██████▍   | 108815/168147 [07:26<04:31, 218.61it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_712_combined_padding-1.mp4
#  65%|██████▍   | 108872/168147 [07:26<03:58, 248.81it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_330_mask_padding-1.mp4
#  68%|██████▊   | 114398/168147 [07:49<03:58, 225.58it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_4244_combined_padding-1.mp4
#  69%|██████▉   | 116061/168147 [07:55<03:25, 253.48it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_15_mask_padding-1.mp4
#  69%|██████▉   | 116681/168147 [07:58<03:35, 238.76it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3740_mask_padding-1.mp4
#  70%|██████▉   | 117676/168147 [08:02<03:31, 238.17it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3005_combined_padding-1.mp4
#  71%|███████   | 118730/168147 [08:07<03:55, 209.49it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_729_combined_padding-1.mp4
#  73%|███████▎  | 121907/168147 [08:19<03:00, 255.81it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_15_raw_padding-1.mp4
#  73%|███████▎  | 122391/168147 [08:21<02:46, 275.46it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3005_raw_padding-1.mp4
#  74%|███████▎  | 123791/168147 [08:27<02:48, 263.04it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1933_combined_padding-1.mp4
#  77%|███████▋  | 129487/168147 [08:50<02:46, 232.10it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_341_raw_padding-1.mp4
#  78%|███████▊  | 131077/168147 [08:57<02:26, 253.04it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_341_combined_padding-1.mp4
#  78%|███████▊  | 131774/168147 [09:00<02:41, 225.42it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1607_combined_padding-1.mp4
#  78%|███████▊  | 131910/168147 [09:00<02:23, 253.16it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_729_raw_padding-1.mp4
#  80%|████████  | 134862/168147 [09:12<02:24, 230.97it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_4597_combined_padding-1.mp4
#  82%|████████▏ | 138124/168147 [09:25<02:06, 236.45it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_1128_combined_padding-1.mp4
#  82%|████████▏ | 138476/168147 [09:27<02:07, 232.93it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_1128_mask_padding-1.mp4
#  84%|████████▍ | 140887/168147 [09:37<01:54, 238.36it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3740_raw_padding-1.mp4
#  86%|████████▌ | 144306/168147 [09:50<01:48, 218.83it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_712_mask_padding-1.mp4
#  89%|████████▉ | 150004/168147 [10:14<01:35, 189.05it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/test_normal_330_combined_padding-1.mp4
#  91%|█████████ | 152546/168147 [10:24<01:03, 246.64it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_4597_mask_padding-1.mp4
#  92%|█████████▏| 154287/168147 [10:32<00:54, 252.83it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3896_raw_padding-1.mp4
#  93%|█████████▎| 157112/168147 [10:43<00:47, 230.85it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_4597_raw_padding-1.mp4
#  98%|█████████▊| 164755/168147 [11:14<00:13, 260.87it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3199_combined_padding-1.mp4
#  99%|█████████▊| 165941/168147 [11:19<00:09, 244.98it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_3199_raw_padding-1.mp4
#  99%|█████████▉| 166667/168147 [11:22<00:05, 247.77it/s]
# invalid video for decord (https://github.com/dmlc/decord/issues/150):  notebook_results/mmaction_train_data_v14-inclusive/videos/train_normal_1060_raw_padding-1.mp4
# 100%|██████████| 168147/168147 [11:28<00:00, 244.23it/s]

# %% [markdown]
# Remove "invalid" videos (cannot be read by decord) from mmdetection

# %%
# extract file names from invalid decord paths
invalid_decord_filenames = set([os.path.basename(path) for path in invalid_decord_paths])

for df_path in mmaction_df_paths:
    _df = pd.read_csv(df_path, sep=" ", header=None)
    # remove all the rows with column "path" in invalid_decord_filenames
    filtered_df = _df[~_df[0].isin(invalid_decord_filenames)]

    df_filename = os.path.basename(df_path)
    # summarize the number of samples for the file
    print(f"df_path: {df_filename}, #filtered: {_df.shape[0] - filtered_df.shape[0]}, original df shape: {_df.shape}, filtered df shape: {filtered_df.shape}")

    # save to the disk
    filtered_df.to_csv(df_path, index=False, header=False, sep=" ")
# Out:
# df_path: mmaction_train_data_video.txt, #filtered: 18, original df shape: (45115, 2), filtered df shape: (45097, 2)
# df_path: mmaction_test_data_video.txt, #filtered: 3, original df shape: (10934, 2), filtered df shape: (10931, 2)
# df_path: mmaction_train_data_mask.txt, #filtered: 18, original df shape: (45115, 2), filtered df shape: (45097, 2)
# df_path: mmaction_test_data_mask.txt, #filtered: 3, original df shape: (10934, 2), filtered df shape: (10931, 2)
# df_path: mmaction_train_data_combined.txt, #filtered: 18, original df shape: (45115, 2), filtered df shape: (45097, 2)
# df_path: mmaction_test_data_combined.txt, #filtered: 3, original df shape: (10934, 2), filtered df shape: (10931, 2)
# df_path: mmaction_train_data_all.txt, #filtered: 54, original df shape: (135345, 2), filtered df shape: (135291, 2)
# df_path: mmaction_test_data_all.txt, #filtered: 9, original df shape: (32802, 2), filtered df shape: (32793, 2)

# %% [markdown]
# check if videos can be loaded by cv2 correctly

# %%
import cv2

cap = cv2.VideoCapture("./test_video_output.mp4")

while True:
    ret, frame = cap.read()
    if not ret:
        break
    assert frame.shape[-1] == 3, "frame should be in RGB format"

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[44], line 12
#       9     assert frame.shape[-1] == 3, "frame should be in RGB format"
#      11 cap.release()
# ---> 12 cv2.destroyAllWindows()
#
# error: OpenCV(4.8.1) /io/opencv/modules/highgui/src/window.cpp:1266: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %%
# from sklearn.model_selection import train_test_split

# train_df_path = data_dir/'train_data.csv'
# test_df_path = data_dir/'test_data.csv'

# # split train and test from df
# train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
# train_df.to_csv(train_df_path, index=False, header=False, sep=' ')
# test_df.to_csv(test_df_path, index=False, header=False, sep=' ')
